# %% [markdown]
# # ExtractingVegetaion Index -VI form Raster data for Italy

# %% [markdown]
# - The raster data model is a widely used method of storing geographic data.
#
# - The model most commonly takes the form of a grid-like structure that holds values at regularly spaced intervals over the extent of the raster
#
# - Cmparwd to vector models raster model represents location as `cells`, also in a `Cartesian coordinate system` whereas vector model represents feature shape accurately.
#
# - The raster model represents rectangular areas and thus is more generalized and less accurate
#
# - Raster GISs have superior **analytical power** to vector GISs

# %% [markdown]
# **1. Importing modules**

# %%
# import Google earth engine module
import ee

#Authenticate the Google earth engine with google account
# First firt setup only, no need to run this after first run


#ee.Authenticate()

# for normal/regular use for authorization
# this is required regularly
ee.Initialize()

# %%
#Pandas modules to interact data
import numpy as np
import pandas as pd

# %% [markdown]
# **2. Define NDVI and EVI for Sentinel-2 image**
#
# - while computing **NDIV** is straightforward, defining expression for **EVI** allow to consider correction factors

# %%
# compute NDVI from NIR and red band in sentinel -2 image
# For other satellite image, please change the band information accordingly

def getNDVI(image):
    
    # Normalized difference vegetation index (NDVI)
    ndvi = image.normalizedDifference(['B8','B4']).rename("NDVI")
    image = image.addBands(ndvi)

    return(image)

# compute EVI from NIR and red band in sentinel -2 image
# For other satellite image, please change the band information accordingly

def getEVI(image):
   # Compute the EVI using an expression.
    EVI = image.expression(
        '2.5 * ((NIR - RED) / (NIR + 6 * RED - 7.5 * BLUE + 1))', {
            'NIR': image.select('B8').divide(10000),
            'RED': image.select('B4').divide(10000),
            'BLUE': image.select('B2').divide(10000)
        }).rename("EVI")

    image = image.addBands(EVI)

    return(image)

# %% [markdown]
# **3 Date parameter for image**
#
# - It is most important part for time series study.
#
# - Followed date format is `YYYYMMdd`

# %%
#add date foramte
def addDate(image):
    img_date = ee.Date(image.date())
    img_date = ee.Number.parse(img_date.format('YYYYMMdd'))
    return image.addBands(ee.Image(img_date).rename('date').toInt())

# %% [markdown]
# **4.Filter the imagery to desired timeframe and other parameters**
#
# - I have limited the filters for sample only.

# %%
Sentinel_data = ee.ImageCollection('COPERNICUS/S2') \
    .filterDate("2020-01-01","2021-08-31") \
    .map(getNDVI).map(getEVI).map(addDate)

# %% [markdown]
# **5. Import location of Cities of Italy.**
#
# Location of Cities of Italy collected [here](https://simplemaps.com/data/it-cities) and cleaned for NDVI and EVI

# %%
import pandas as pd
df_itally = pd.read_excel('C:\\Users\\user\\OneDrive\\Desktop\\Omdena_Milna\\Italy_Cities.xlsx')
df_itally.head()
# Out:
#       city      lat      lng country iso2 admin_name  capital  population  \
# 0     Rome  41.8931  12.4828   Italy   IT      Lazio  primary     2872800
# 1    Milan  45.4669   9.1900   Italy   IT   Lombardy    admin     1366180
# 2   Naples  40.8333  14.2500   Italy   IT   Campania    admin      966144
# 3    Turin  45.0667   7.7000   Italy   IT   Piedmont    admin      870952
# 4  Palermo  38.1157  13.3613   Italy   IT    Sicilia    admin      668405
#
#    population_proper
# 0            2872800
# 1            1366180
# 2             966144
# 3             870952
# 4             668405

# %%
df_itally.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3373 entries, 0 to 3372
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   city               3373 non-null   object
#  1   lat                3373 non-null   float64
#  2   lng                3373 non-null   float64
#  3   country            3373 non-null   object
#  4   iso2               3373 non-null   object
#  5   admin_name         3373 non-null   object
#  6   capital            115 non-null    object
#  7   population         3373 non-null   int64
#  8   population_proper  3373 non-null   int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 237.3+ KB

# %% [markdown]
# - Only, **City**, **lat** and **lng** are essentisl to our analysis, hence we drop others

# %%
italy_df =df_itally.drop(columns=['country','iso2','admin_name','capital','admin_name','population','population_proper'],axis=1)
italy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3373 entries, 0 to 3372
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   city    3373 non-null   object
#  1   lat     3373 non-null   float64
#  2   lng     3373 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 79.2+ KB

# %% [markdown]
# **6.Convert the pandas dataframe into Google Earth Engine (GEE) Feature Collection**
#
# - This is to constrcu  a point geometry for each City based on thier  coordinates
#
# - another important issue is `proprty of the point constructed` that can be invoked as dictionary

# %%
features=[]
for index, row in italy_df.iterrows():
    poi_geometry = ee.Geometry.Point([row['lat'], row['lng']])
#     print(poi_geometry)
#     construct the attributes (properties) for each point 
    poi_properties = dict(row)
#     construct feature combining geometry and properties
    poi_feature = ee.Feature(poi_geometry, poi_properties)
    features.append(poi_feature)

    # final Feature collection assembly
ee_fc = ee.FeatureCollection(features) 
ee_fc.getInfo()
# Out:
# {'type': 'FeatureCollection',
#  'columns': {'city': 'String',
#   'lat': 'Number',
#   'lng': 'Number',
#   'system:index': 'String'},
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.8931, 12.4828]},
#    'id': '0',
#    'properties': {'city': 'Rome', 'lat': 41.8931, 'lng': 12.4828}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.4669, 9.19]},
#    'id': '1',
#    'properties': {'city': 'Milan', 'lat': 45.4669, 'lng': 9.19}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.8333, 14.25]},
#    'id': '2',
#    'properties': {'city': 'Naples', 'lat': 40.8333, 'lng': 14.25}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.0667, 7.7]},
#    'id': '3',
#    'properties': {'city': 'Turin', 'lat': 45.0667, 'lng': 7.7}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [38.1157, 13.3613]},
#    'id': '4',
#    'properties': {'city': 'Palermo', 'lat': 38.1157, 'lng': 13.3613}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.4072, 8.934]},
#    'id': '5',
#    'properties': {'city': 'Genoa', 'lat': 44.4072, 'lng': 8.934}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.4939, 11.3428]},
#    'id': '6',
#    'properties': {'city': 'Bologna', 'lat': 44.4939, 'lng': 11.3428}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.7714, 11.2542]},
#    'id': '7',
#    'properties': {'city': 'Florence', 'lat': 43.7714, 'lng': 11.2542}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.1253, 16.8667]},
#    'id': '8',
#    'properties': {'city': 'Bari', 'lat': 41.1253, 'lng': 16.8667}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.5027, 15.0873]},
#    'id': '9',
#    'properties': {'city': 'Catania', 'lat': 37.5027, 'lng': 15.0873}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.4397, 12.3319]},
#    'id': '10',
#    'properties': {'city': 'Venice', 'lat': 45.4397, 'lng': 12.3319}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.4386, 10.9928]},
#    'id': '11',
#    'properties': {'city': 'Verona', 'lat': 45.4386, 'lng': 10.9928}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [38.1936, 15.5542]},
#    'id': '12',
#    'properties': {'city': 'Messina', 'lat': 38.1936, 'lng': 15.5542}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.4064, 11.8778]},
#    'id': '13',
#    'properties': {'city': 'Padova', 'lat': 45.4064, 'lng': 11.8778}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.6503, 13.7703]},
#    'id': '14',
#    'properties': {'city': 'Trieste', 'lat': 45.6503, 'lng': 13.7703}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.4181, 17.2408]},
#    'id': '15',
#    'properties': {'city': 'Taranto', 'lat': 40.4181, 'lng': 17.2408}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.5389, 10.2203]},
#    'id': '16',
#    'properties': {'city': 'Brescia', 'lat': 45.5389, 'lng': 10.2203}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.8015, 10.328]},
#    'id': '17',
#    'properties': {'city': 'Parma', 'lat': 44.8015, 'lng': 10.328}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.8808, 11.0966]},
#    'id': '18',
#    'properties': {'city': 'Prato', 'lat': 43.8808, 'lng': 11.0966}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.6458, 10.9257]},
#    'id': '19',
#    'properties': {'city': 'Modena', 'lat': 44.6458, 'lng': 10.9257}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [38.1144, 15.65]},
#    'id': '20',
#    'properties': {'city': 'Reggio di Calabria', 'lat': 38.1144, 'lng': 15.65}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.7, 10.6333]},
#    'id': '21',
#    'properties': {'city': 'Reggio Emilia', 'lat': 44.7, 'lng': 10.6333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.1121, 12.3888]},
#    'id': '22',
#    'properties': {'city': 'Perugia', 'lat': 43.1121, 'lng': 12.3888}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.4178, 12.1994]},
#    'id': '23',
#    'properties': {'city': 'Ravenna', 'lat': 44.4178, 'lng': 12.1994}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.55, 10.3167]},
#    'id': '24',
#    'properties': {'city': 'Livorno', 'lat': 43.55, 'lng': 10.3167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [39.2167, 9.1167]},
#    'id': '25',
#    'properties': {'city': 'Cagliari', 'lat': 39.2167, 'lng': 9.1167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.4584, 15.5519]},
#    'id': '26',
#    'properties': {'city': 'Foggia', 'lat': 41.4584, 'lng': 15.5519}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.0594, 12.5683]},
#    'id': '27',
#    'properties': {'city': 'Rimini', 'lat': 44.0594, 'lng': 12.5683}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.6806, 14.7597]},
#    'id': '28',
#    'properties': {'city': 'Salerno', 'lat': 40.6806, 'lng': 14.7597}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.8353, 11.6199]},
#    'id': '29',
#    'properties': {'city': 'Ferrara', 'lat': 44.8353, 'lng': 11.6199}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.4676, 12.9037]},
#    'id': '30',
#    'properties': {'city': 'Latina', 'lat': 41.4676, 'lng': 12.9037}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.9319, 14.1956]},
#    'id': '31',
#    'properties': {'city': 'Giugliano in Campania',
#     'lat': 40.9319,
#     'lng': 14.1956}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.5836, 9.2736]},
#    'id': '32',
#    'properties': {'city': 'Monza', 'lat': 45.5836, 'lng': 9.2736}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.0692, 15.2875]},
#    'id': '33',
#    'properties': {'city': 'Siracusa', 'lat': 37.0692, 'lng': 15.2875}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.695, 9.67]},
#    'id': '34',
#    'properties': {'city': 'Bergamo', 'lat': 45.695, 'lng': 9.67}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42.4643, 14.2142]},
#    'id': '35',
#    'properties': {'city': 'Pescara', 'lat': 42.4643, 'lng': 14.2142}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [46.0667, 11.1167]},
#    'id': '36',
#    'properties': {'city': 'Trento', 'lat': 46.0667, 'lng': 11.1167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.2225, 12.0408]},
#    'id': '37',
#    'properties': {'city': 'Forlì', 'lat': 44.2225, 'lng': 12.0408}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.7267, 8.5592]},
#    'id': '38',
#    'properties': {'city': 'Sassari', 'lat': 40.7267, 'lng': 8.5592}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.55, 11.55]},
#    'id': '39',
#    'properties': {'city': 'Vicenza', 'lat': 45.55, 'lng': 11.55}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42.5667, 12.65]},
#    'id': '40',
#    'properties': {'city': 'Terni', 'lat': 42.5667, 'lng': 12.65}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [46.5, 11.35]},
#    'id': '41',
#    'properties': {'city': 'Bolzano', 'lat': 46.5, 'lng': 11.35}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.45, 8.6167]},
#    'id': '42',
#    'properties': {'city': 'Novara', 'lat': 45.45, 'lng': 8.6167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.05, 9.7]},
#    'id': '43',
#    'properties': {'city': 'Piacenza', 'lat': 45.05, 'lng': 9.7}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.6167, 13.5167]},
#    'id': '44',
#    'properties': {'city': 'Ancona', 'lat': 43.6167, 'lng': 13.5167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.2317, 16.3083]},
#    'id': '45',
#    'properties': {'city': 'Andria', 'lat': 41.2317, 'lng': 16.3083}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [46.0667, 13.2333]},
#    'id': '46',
#    'properties': {'city': 'Udine', 'lat': 46.0667, 'lng': 13.2333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.4631, 11.8781]},
#    'id': '47',
#    'properties': {'city': 'Arezzo', 'lat': 43.4631, 'lng': 11.8781}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.1333, 12.2333]},
#    'id': '48',
#    'properties': {'city': 'Cesena', 'lat': 44.1333, 'lng': 12.2333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.352, 18.1691]},
#    'id': '49',
#    'properties': {'city': 'Lecce', 'lat': 40.352, 'lng': 18.1691}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.9102, 12.9133]},
#    'id': '50',
#    'properties': {'city': 'Pesaro', 'lat': 43.9102, 'lng': 12.9133}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.3167, 16.2833]},
#    'id': '51',
#    'properties': {'city': 'Barletta', 'lat': 41.3167, 'lng': 16.2833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.9133, 8.62]},
#    'id': '52',
#    'properties': {'city': 'Alessandria', 'lat': 44.9133, 'lng': 8.62}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.108, 9.8289]},
#    'id': '53',
#    'properties': {'city': 'La Spezia', 'lat': 44.108, 'lng': 9.8289}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.9333, 10.9167]},
#    'id': '54',
#    'properties': {'city': 'Pistoia', 'lat': 43.9333, 'lng': 10.9167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.7167, 10.4]},
#    'id': '55',
#    'properties': {'city': 'Pisa', 'lat': 43.7167, 'lng': 10.4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [38.91, 16.5875]},
#    'id': '56',
#    'properties': {'city': 'Catanzaro', 'lat': 38.91, 'lng': 16.5875}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.4906, 12.2381]},
#    'id': '57',
#    'properties': {'city': 'Mestre', 'lat': 45.4906, 'lng': 12.2381}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.85, 10.5167]},
#    'id': '58',
#    'properties': {'city': 'Lucca', 'lat': 43.85, 'lng': 10.5167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.6383, 17.9458]},
#    'id': '59',
#    'properties': {'city': 'Brindisi', 'lat': 40.6383, 'lng': 17.9458}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.7853, 14.3953]},
#    'id': '60',
#    'properties': {'city': 'Torre del Greco', 'lat': 40.7853, 'lng': 14.3953}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.6722, 12.2422]},
#    'id': '61',
#    'properties': {'city': 'Treviso', 'lat': 45.6722, 'lng': 12.2422}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.612, 8.8518]},
#    'id': '62',
#    'properties': {'city': 'Busto Arsizio', 'lat': 45.612, 'lng': 8.8518}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.8103, 9.0861]},
#    'id': '63',
#    'properties': {'city': 'Como', 'lat': 45.8103, 'lng': 9.0861}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.7981, 12.4342]},
#    'id': '64',
#    'properties': {'city': 'Marsala', 'lat': 37.7981, 'lng': 12.4342}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42.7722, 11.1089]},
#    'id': '65',
#    'properties': {'city': 'Grosseto', 'lat': 42.7722, 'lng': 11.1089}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.5333, 9.2333]},
#    'id': '66',
#    'properties': {'city': 'Sesto San Giovanni',
#     'lat': 45.5333,
#     'lng': 9.2333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.8231, 14.1222]},
#    'id': '67',
#    'properties': {'city': 'Pozzuoli', 'lat': 40.8231, 'lng': 14.1222}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.8167, 8.8333]},
#    'id': '68',
#    'properties': {'city': 'Varese', 'lat': 45.8167, 'lng': 8.8333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.7667, 12.2333]},
#    'id': '69',
#    'properties': {'city': 'Fiumicino', 'lat': 41.7667, 'lng': 12.2333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.9, 14.3]},
#    'id': '70',
#    'properties': {'city': 'Casoria', 'lat': 40.9, 'lng': 14.3}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.9, 8.2069]},
#    'id': '71',
#    'properties': {'city': 'Asti', 'lat': 44.9, 'lng': 8.2069}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.55, 9.2167]},
#    'id': '72',
#    'properties': {'city': 'Cinisello Balsamo', 'lat': 45.55, 'lng': 9.2167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.0667, 14.3333]},
#    'id': '73',
#    'properties': {'city': 'Caserta', 'lat': 41.0667, 'lng': 14.3333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.0667, 14.25]},
#    'id': '74',
#    'properties': {'city': 'Gela', 'lat': 37.0667, 'lng': 14.25}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [36.925, 14.7306]},
#    'id': '75',
#    'properties': {'city': 'Ragusa', 'lat': 36.925, 'lng': 14.7306}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.1853, 9.155]},
#    'id': '76',
#    'properties': {'city': 'Pavia', 'lat': 45.1853, 'lng': 9.155}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.1333, 10.0333]},
#    'id': '77',
#    'properties': {'city': 'Cremona', 'lat': 45.1333, 'lng': 10.0333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.7833, 10.885]},
#    'id': '78',
#    'properties': {'city': 'Carpi', 'lat': 44.7833, 'lng': 10.885}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [39.2291, 9.2649]},
#    'id': '79',
#    'properties': {'city': 'Quartu Sant’Elena', 'lat': 39.2291, 'lng': 9.2649}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.8167, 16.55]},
#    'id': '80',
#    'properties': {'city': 'Altamura', 'lat': 40.8167, 'lng': 16.55}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.3531, 11.7147]},
#    'id': '81',
#    'properties': {'city': 'Imola', 'lat': 44.3531, 'lng': 11.7147}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42.354, 13.392]},
#    'id': '82',
#    'properties': {'city': 'L’Aquila', 'lat': 42.354, 'lng': 13.392}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.0333, 10.1333]},
#    'id': '83',
#    'properties': {'city': 'Massa', 'lat': 44.0333, 'lng': 10.1333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [38.0175, 12.515]},
#    'id': '84',
#    'properties': {'city': 'Trapani', 'lat': 38.0175, 'lng': 12.515}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42.4186, 12.1042]},
#    'id': '85',
#    'properties': {'city': 'Viterbo', 'lat': 42.4186, 'lng': 12.1042}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [39.3, 16.25]},
#    'id': '86',
#    'properties': {'city': 'Cosenza', 'lat': 39.3, 'lng': 16.25}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.6333, 15.8]},
#    'id': '87',
#    'properties': {'city': 'Potenza', 'lat': 40.6333, 'lng': 15.8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.7, 14.4833]},
#    'id': '88',
#    'properties': {'city': 'Castellammare di Stabia',
#     'lat': 40.7,
#     'lng': 14.4833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.9167, 14.3167]},
#    'id': '89',
#    'properties': {'city': 'Afragola', 'lat': 40.9167, 'lng': 14.3167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [36.95, 14.5333]},
#    'id': '90',
#    'properties': {'city': 'Vittoria', 'lat': 36.95, 'lng': 14.5333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [39.0833, 17.1167]},
#    'id': '91',
#    'properties': {'city': 'Crotone', 'lat': 39.0833, 'lng': 17.1167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.6693, 12.5021]},
#    'id': '92',
#    'properties': {'city': 'Pomezia', 'lat': 41.6693, 'lng': 12.5021}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.3167, 8.8667]},
#    'id': '93',
#    'properties': {'city': 'Vigevano', 'lat': 45.3167, 'lng': 8.8667}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.0833, 10.1]},
#    'id': '94',
#    'properties': {'city': 'Carrara', 'lat': 44.0833, 'lng': 10.1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.4915, 14.0624]},
#    'id': '95',
#    'properties': {'city': 'Caltanissetta', 'lat': 37.4915, 'lng': 14.0624}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.8672, 10.2506]},
#    'id': '96',
#    'properties': {'city': 'Viareggio', 'lat': 43.8672, 'lng': 10.2506}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.1256, 14.7811]},
#    'id': '97',
#    'properties': {'city': 'Benevento', 'lat': 41.1256, 'lng': 14.7811}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.8435, 13.0198]},
#    'id': '98',
#    'properties': {'city': 'Fano', 'lat': 43.8435, 'lng': 13.0198}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.308, 8.481]},
#    'id': '99',
#    'properties': {'city': 'Savona', 'lat': 44.308, 'lng': 8.481}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.6667, 16.6]},
#    'id': '100',
#    'properties': {'city': 'Matera', 'lat': 40.6667, 'lng': 16.6}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.9167, 9.5]},
#    'id': '101',
#    'properties': {'city': 'Olbia', 'lat': 40.9167, 'lng': 9.5}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.5781, 8.9183]},
#    'id': '102',
#    'properties': {'city': 'Legnano', 'lat': 45.5781, 'lng': 8.9183}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.95, 14.3667]},
#    'id': '103',
#    'properties': {'city': 'Acerra', 'lat': 40.95, 'lng': 14.3667}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.9, 14.1833]},
#    'id': '104',
#    'properties': {'city': 'Marano di Napoli', 'lat': 40.9, 'lng': 14.1833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.2, 16.6]},
#    'id': '105',
#    'properties': {'city': 'Molfetta', 'lat': 41.2, 'lng': 16.6}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.3111, 13.5765]},
#    'id': '106',
#    'properties': {'city': 'Agrigento', 'lat': 37.3111, 'lng': 13.5765}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.2856, 11.8833]},
#    'id': '107',
#    'properties': {'city': 'Faenza', 'lat': 44.2856, 'lng': 11.8833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.2667, 15.9]},
#    'id': '108',
#    'properties': {'city': 'Cerignola', 'lat': 41.2667, 'lng': 15.9}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45, 7.6833]},
#    'id': '109',
#    'properties': {'city': 'Moncalieri', 'lat': 45, 'lng': 7.6833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42.9561, 12.7033]},
#    'id': '110',
#    'properties': {'city': 'Foligno', 'lat': 42.9561, 'lng': 12.7033}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.6333, 15.9167]},
#    'id': '111',
#    'properties': {'city': 'Manfredonia', 'lat': 41.6333, 'lng': 15.9167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.9667, 12.8]},
#    'id': '112',
#    'properties': {'city': 'Tivoli', 'lat': 41.9667, 'lng': 12.8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.3833, 7.55]},
#    'id': '113',
#    'properties': {'city': 'Cuneo', 'lat': 44.3833, 'lng': 7.55}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.2667, 16.4167]},
#    'id': '114',
#    'properties': {'city': 'Trani', 'lat': 41.2667, 'lng': 16.4167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.2409, 16.5021]},
#    'id': '115',
#    'properties': {'city': 'Bisceglie', 'lat': 41.2409, 'lng': 16.5021}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.1083, 16.6917]},
#    'id': '116',
#    'properties': {'city': 'Bitonto', 'lat': 41.1083, 'lng': 16.6917}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [38.0833, 13.5]},
#    'id': '117',
#    'properties': {'city': 'Bagheria', 'lat': 38.0833, 'lng': 13.5}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.8197, 14.3411]},
#    'id': '118',
#    'properties': {'city': 'Portici', 'lat': 40.8197, 'lng': 14.3411}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [36.8672, 14.7614]},
#    'id': '119',
#    'properties': {'city': 'Modica', 'lat': 36.8672, 'lng': 14.7614}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.8175, 7.775]},
#    'id': '120',
#    'properties': {'city': 'San Remo', 'lat': 43.8175, 'lng': 7.775}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42.6589, 13.7039]},
#    'id': '121',
#    'properties': {'city': 'Teramo', 'lat': 42.6589, 'lng': 13.7039}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42.5119, 14.1373]},
#    'id': '122',
#    'properties': {'city': 'Montesilvano', 'lat': 42.5119, 'lng': 14.1373}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.9153, 14.7897]},
#    'id': '123',
#    'properties': {'city': 'Avellino', 'lat': 40.9153, 'lng': 14.7897}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.3183, 11.3314]},
#    'id': '124',
#    'properties': {'city': 'Siena', 'lat': 43.3183, 'lng': 11.3314}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.6649, 8.7914]},
#    'id': '125',
#    'properties': {'city': 'Gallarate', 'lat': 45.6649, 'lng': 8.7914}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.6667, 12.7833]},
#    'id': '126',
#    'properties': {'city': 'Velletri', 'lat': 41.6667, 'lng': 12.7833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.7008, 14.7056]},
#    'id': '127',
#    'properties': {'city': 'Cava de’ Tirreni', 'lat': 40.7008, 'lng': 14.7056}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.6951, 15.3793]},
#    'id': '128',
#    'properties': {'city': 'San Severo', 'lat': 41.6951, 'lng': 15.3793}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.973, 14.2065]},
#    'id': '129',
#    'properties': {'city': 'Aversa', 'lat': 40.973, 'lng': 14.2065}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.8068, 14.3526]},
#    'id': '130',
#    'properties': {'city': 'Ercolano', 'lat': 40.8068, 'lng': 14.3526}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.4472, 12.6283]},
#    'id': '131',
#    'properties': {'city': 'Anzio', 'lat': 41.4472, 'lng': 12.6283}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.6125, 15.1656]},
#    'id': '132',
#    'properties': {'city': 'Acireale', 'lat': 37.6125, 'lng': 15.1656}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42.1, 11.8]},
#    'id': '133',
#    'properties': {'city': 'Civitavecchia', 'lat': 42.1, 'lng': 11.8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.6517, 12.5875]},
#    'id': '134',
#    'properties': {'city': 'Mazara del Vallo', 'lat': 37.6517, 'lng': 12.5875}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.0809, 11.794]},
#    'id': '135',
#    'properties': {'city': 'Rovigo', 'lat': 45.0809, 'lng': 11.794}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.9626, 12.6563]},
#    'id': '136',
#    'properties': {'city': 'Pordenone', 'lat': 45.9626, 'lng': 12.6563}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.6167, 14.9833]},
#    'id': '137',
#    'properties': {'city': 'Battipaglia', 'lat': 40.6167, 'lng': 14.9833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.5333, 9.0333]},
#    'id': '138',
#    'properties': {'city': 'Rho', 'lat': 45.5333, 'lng': 9.0333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42.3511, 14.1674]},
#    'id': '139',
#    'properties': {'city': 'Chieti', 'lat': 42.3511, 'lng': 14.1674}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.7536, 14.5253]},
#    'id': '140',
#    'properties': {'city': 'Scafati', 'lat': 40.7536, 'lng': 14.5253}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.7544, 11.1894]},
#    'id': '141',
#    'properties': {'city': 'Scandicci', 'lat': 43.7544, 'lng': 11.1894}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.5183, 15.0069]},
#    'id': '142',
#    'properties': {'city': 'Misterbianco', 'lat': 37.5183, 'lng': 15.0069}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.4667, 12.6667]},
#    'id': '143',
#    'properties': {'city': 'Nettuno', 'lat': 41.4667, 'lng': 12.6667}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.6167, 12.55]},
#    'id': '144',
#    'properties': {'city': 'Ardea', 'lat': 41.6167, 'lng': 12.55}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.0833, 7.5833]},
#    'id': '145',
#    'properties': {'city': 'Collegno', 'lat': 45.0833, 'lng': 7.5833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.2189, 12.2785]},
#    'id': '146',
#    'properties': {'city': 'Chioggia', 'lat': 45.2189, 'lng': 12.2785}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.1564, 10.7911]},
#    'id': '147',
#    'properties': {'city': 'Mantova', 'lat': 45.1564, 'lng': 10.7911}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.561, 14.6684]},
#    'id': '148',
#    'properties': {'city': 'Campobasso', 'lat': 41.561, 'lng': 14.6684}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.9167, 14.35]},
#    'id': '149',
#    'properties': {'city': 'Casalnuovo di Napoli',
#     'lat': 40.9167,
#     'lng': 14.35}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.8333, 11.2]},
#    'id': '150',
#    'properties': {'city': 'Sesto Fiorentino', 'lat': 43.8333, 'lng': 11.2}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.95, 17.3]},
#    'id': '151',
#    'properties': {'city': 'Monopoli', 'lat': 40.95, 'lng': 17.3}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.7, 17.3333]},
#    'id': '152',
#    'properties': {'city': 'Martina Franca', 'lat': 40.7, 'lng': 17.3333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42.8547, 13.5753]},
#    'id': '153',
#    'properties': {'city': 'Ascoli Piceno', 'lat': 42.8547, 'lng': 13.5753}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.0725, 7.5272]},
#    'id': '154',
#    'properties': {'city': 'Rivoli', 'lat': 45.0725, 'lng': 7.5272}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.7167, 10.95]},
#    'id': '155',
#    'properties': {'city': 'Empoli', 'lat': 43.7167, 'lng': 10.95}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.15, 16.4]},
#    'id': '156',
#    'properties': {'city': 'Corato', 'lat': 41.15, 'lng': 16.4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.85, 9.4]},
#    'id': '157',
#    'properties': {'city': 'Lecco', 'lat': 45.85, 'lng': 9.4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.5667, 14.9]},
#    'id': '158',
#    'properties': {'city': 'Paterno', 'lat': 37.5667, 'lng': 14.9}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45, 7.65]},
#    'id': '159',
#    'properties': {'city': 'Nichelino', 'lat': 45, 'lng': 7.65}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.5286, 9.2783]},
#    'id': '160',
#    'properties': {'city': 'Cologno Monzese', 'lat': 45.5286, 'lng': 9.2783}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42.4044, 12.8567]},
#    'id': '161',
#    'properties': {'city': 'Rieti', 'lat': 42.4044, 'lng': 12.8567}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42.9438, 13.8833]},
#    'id': '162',
#    'properties': {'city': 'San Benedetto del Tronto',
#     'lat': 42.9438,
#     'lng': 13.8833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.1333, 7.7667]},
#    'id': '163',
#    'properties': {'city': 'Settimo Torinese', 'lat': 45.1333, 'lng': 7.7667}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.5667, 9.1667]},
#    'id': '164',
#    'properties': {'city': 'Paderno Dugnano', 'lat': 45.5667, 'lng': 9.1667}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.8256, 11.1333]},
#    'id': '165',
#    'properties': {'city': 'Campi Bisenzio', 'lat': 43.8256, 'lng': 11.1333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.2833, 13.25]},
#    'id': '166',
#    'properties': {'city': 'Terracina', 'lat': 41.2833, 'lng': 13.25}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.3167, 8.4167]},
#    'id': '167',
#    'properties': {'city': 'Vercelli', 'lat': 45.3167, 'lng': 8.4167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.8756, 10.5736]},
#    'id': '168',
#    'properties': {'city': 'Capannori', 'lat': 43.8756, 'lng': 10.5736}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.6333, 13.35]},
#    'id': '169',
#    'properties': {'city': 'Frosinone', 'lat': 41.6333, 'lng': 13.35}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.75, 14.6333]},
#    'id': '170',
#    'properties': {'city': 'Nocera Inferiore', 'lat': 40.75, 'lng': 14.6333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.6167, 9.25]},
#    'id': '171',
#    'properties': {'city': 'Lissone', 'lat': 45.6167, 'lng': 9.25}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.9667, 12.9667]},
#    'id': '172',
#    'properties': {'city': 'Alcamo', 'lat': 37.9667, 'lng': 12.9667}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.3167, 9.5]},
#    'id': '173',
#    'properties': {'city': 'Lodi', 'lat': 45.3167, 'lng': 9.5}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.68, 10.5003]},
#    'id': '174',
#    'properties': {'city': 'Cascina', 'lat': 43.68, 'lng': 10.5003}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.65, 9.2]},
#    'id': '175',
#    'properties': {'city': 'Seregno', 'lat': 45.65, 'lng': 9.2}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.8333, 14.3333]},
#    'id': '176',
#    'properties': {'city': 'San Giorgio a Cremano',
#     'lat': 40.8333,
#     'lng': 14.3333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.7131, 13.2183]},
#    'id': '177',
#    'properties': {'city': 'Senigallia', 'lat': 43.7131, 'lng': 13.2183}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.7667, 12.6667]},
#    'id': '178',
#    'properties': {'city': 'Marino', 'lat': 41.7667, 'lng': 12.6667}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.5664, 8.0533]},
#    'id': '179',
#    'properties': {'city': 'Biella', 'lat': 45.5664, 'lng': 8.0533}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.56, 8.315]},
#    'id': '180',
#    'properties': {'city': 'Alghero', 'lat': 40.56, 'lng': 8.315}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.8206, 16.4233]},
#    'id': '181',
#    'properties': {'city': 'Gravina in Puglia',
#     'lat': 40.8206,
#     'lng': 16.4233}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.7686, 11.7367]},
#    'id': '182',
#    'properties': {'city': 'Bassano del Grappa',
#     'lat': 45.7686,
#     'lng': 11.7367}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.3833, 9.15]},
#    'id': '183',
#    'properties': {'city': 'Rozzano', 'lat': 45.3833, 'lng': 9.15}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.7569, 14.4444]},
#    'id': '184',
#    'properties': {'city': 'Torre Annunziata', 'lat': 40.7569, 'lng': 14.4444}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.3068, 13.7286]},
#    'id': '185',
#    'properties': {'city': 'Civitanova Marche',
#     'lat': 43.3068,
#     'lng': 13.7286}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.8865, 8.0297]},
#    'id': '186',
#    'properties': {'city': 'Imperia', 'lat': 43.8865, 'lng': 8.0297}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42.031, 13.4264]},
#    'id': '187',
#    'properties': {'city': 'Avezzano', 'lat': 42.031, 'lng': 13.4264}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.6167, 9.2167]},
#    'id': '188',
#    'properties': {'city': 'Desio', 'lat': 45.6167, 'lng': 9.2167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.6298, 12.5641]},
#    'id': '189',
#    'properties': {'city': 'San Donà di Piave',
#     'lat': 45.6298,
#     'lng': 12.5641}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.3003, 13.4533]},
#    'id': '190',
#    'properties': {'city': 'Macerata', 'lat': 43.3003, 'lng': 13.4533}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.9544, 12.0742]},
#    'id': '191',
#    'properties': {'city': 'Ladispoli', 'lat': 41.9544, 'lng': 12.0742}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [38.15, 15.2167]},
#    'id': '192',
#    'properties': {'city': 'Barcellona-Pozzo di Gotto',
#     'lat': 38.15,
#     'lng': 15.2167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.7333, 12.6667]},
#    'id': '193',
#    'properties': {'city': 'Albano Laziale', 'lat': 41.7333, 'lng': 12.6667}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42.05, 12.6167]},
#    'id': '194',
#    'properties': {'city': 'Monterotondo', 'lat': 42.05, 'lng': 12.6167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.5517, 10.7856]},
#    'id': '195',
#    'properties': {'city': 'Sassuolo', 'lat': 44.5517, 'lng': 10.7856}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.5092, 13.0889]},
#    'id': '196',
#    'properties': {'city': 'Sciacca', 'lat': 37.5092, 'lng': 13.0889}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [46.6689, 11.1639]},
#    'id': '197',
#    'properties': {'city': 'Merano', 'lat': 46.6689, 'lng': 11.1639}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [39.6, 16.5167]},
#    'id': '198',
#    'properties': {'city': 'Corigliano Calabro', 'lat': 39.6, 'lng': 16.5167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.5228, 13.2439]},
#    'id': '199',
#    'properties': {'city': 'Iesi', 'lat': 43.5228, 'lng': 13.2439}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.6169, 15.0564]},
#    'id': '200',
#    'properties': {'city': 'Eboli', 'lat': 40.6169, 'lng': 15.0564}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.7333, 9.1333]},
#    'id': '201',
#    'properties': {'city': 'Cantù', 'lat': 45.7333, 'lng': 9.1333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.8833, 11.0342]},
#    'id': '202',
#    'properties': {'city': 'Rovereto', 'lat': 45.8833, 'lng': 11.0342}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.9167, 14.4]},
#    'id': '203',
#    'properties': {'city': 'Pomigliano d’Arco', 'lat': 40.9167, 'lng': 14.4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.0333, 14.3]},
#    'id': '204',
#    'properties': {'city': 'Marcianise', 'lat': 41.0333, 'lng': 14.3}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.35, 13.4167]},
#    'id': '205',
#    'properties': {'city': 'Fondi', 'lat': 41.35, 'lng': 13.4167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.8333, 17.3667]},
#    'id': '206',
#    'properties': {'city': 'Fasano', 'lat': 40.8333, 'lng': 17.3667}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.4574, 12.2403]},
#    'id': '207',
#    'properties': {'city': 'Città di Castello',
#     'lat': 43.4574,
#     'lng': 12.2403}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.6255, 9.037]},
#    'id': '208',
#    'properties': {'city': 'Saronno', 'lat': 45.6255, 'lng': 9.037}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.9925, 9.0092]},
#    'id': '209',
#    'properties': {'city': 'Voghera', 'lat': 44.9925, 'lng': 9.0092}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.7111, 11.3556]},
#    'id': '210',
#    'properties': {'city': 'Schio', 'lat': 45.7111, 'lng': 11.3556}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [38.0817, 13.2889]},
#    'id': '211',
#    'properties': {'city': 'Monreale', 'lat': 38.0817, 'lng': 13.2889}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.0333, 14.3833]},
#    'id': '212',
#    'properties': {'city': 'Maddaloni', 'lat': 41.0333, 'lng': 14.3833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [38.1333, 13.1833]},
#    'id': '213',
#    'properties': {'city': 'Carini', 'lat': 38.1333, 'lng': 13.1833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.8, 12.6]},
#    'id': '214',
#    'properties': {'city': 'Ciampino', 'lat': 41.8, 'lng': 12.6}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.6272, 9.1472]},
#    'id': '215',
#    'properties': {'city': 'Cesano Maderno', 'lat': 45.6272, 'lng': 9.1472}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.4375, 12.1329]},
#    'id': '216',
#    'properties': {'city': 'Mira', 'lat': 45.4375, 'lng': 12.1329}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.0833, 16.7833]},
#    'id': '217',
#    'properties': {'city': 'Modugno', 'lat': 41.0833, 'lng': 16.7833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.4, 9.2833]},
#    'id': '218',
#    'properties': {'city': 'San Giuliano Milanese',
#     'lat': 45.4,
#     'lng': 9.2833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.2333, 14.5167]},
#    'id': '219',
#    'properties': {'city': 'Caltagirone', 'lat': 37.2333, 'lng': 14.5167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.2564, 13.6069]},
#    'id': '220',
#    'properties': {'city': 'Formia', 'lat': 41.2564, 'lng': 13.6069}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42, 12.1]},
#    'id': '221',
#    'properties': {'city': 'Cerveteri', 'lat': 42, 'lng': 12.1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42.7333, 12.7333]},
#    'id': '222',
#    'properties': {'city': 'Spoleto', 'lat': 42.7333, 'lng': 12.7333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.9167, 14.2333]},
#    'id': '223',
#    'properties': {'city': 'Melito di Napoli', 'lat': 40.9167, 'lng': 14.2333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.95, 14.3]},
#    'id': '224',
#    'properties': {'city': 'Caivano', 'lat': 40.95, 'lng': 14.3}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.0689, 7.5786]},
#    'id': '225',
#    'properties': {'city': 'Grugliasco', 'lat': 45.0689, 'lng': 7.5786}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.1604, 13.7181]},
#    'id': '226',
#    'properties': {'city': 'Fermo', 'lat': 43.1604, 'lng': 13.7181}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.1083, 13.9469]},
#    'id': '227',
#    'properties': {'city': 'Licata', 'lat': 37.1083, 'lng': 13.9469}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.6, 12.8333]},
#    'id': '228',
#    'properties': {'city': 'Cisterna di Latina', 'lat': 41.6, 'lng': 12.8333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.0131, 7.8228]},
#    'id': '229',
#    'properties': {'city': 'Chieri', 'lat': 45.0131, 'lng': 7.8228}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.5, 9.3333]},
#    'id': '230',
#    'properties': {'city': 'Pioltello', 'lat': 45.5, 'lng': 9.3333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [39.5667, 16.6333]},
#    'id': '231',
#    'properties': {'city': 'Rossano', 'lat': 39.5667, 'lng': 16.6333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.3201, 9.3281]},
#    'id': '232',
#    'properties': {'city': 'Nuoro', 'lat': 40.3201, 'lng': 9.3281}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.4917, 13.8333]},
#    'id': '233',
#    'properties': {'city': 'Cassino', 'lat': 41.4917, 'lng': 13.8333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.55, 9.1167]},
#    'id': '234',
#    'properties': {'city': 'Bollate', 'lat': 45.55, 'lng': 9.1167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.4833, 11.2833]},
#    'id': '235',
#    'properties': {'city': 'Casalecchio di Reno',
#     'lat': 44.4833,
#     'lng': 11.2833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.5314, 17.5858]},
#    'id': '236',
#    'properties': {'city': 'Francavilla Fontana',
#     'lat': 40.5314,
#     'lng': 17.5858}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.8833, 7.3333]},
#    'id': '237',
#    'properties': {'city': 'Pinerolo', 'lat': 44.8833, 'lng': 7.3333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.2303, 15.2194]},
#    'id': '238',
#    'properties': {'city': 'Augusta', 'lat': 37.2303, 'lng': 15.2194}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [39.3333, 16.1833]},
#    'id': '239',
#    'properties': {'city': 'Rende', 'lat': 39.3333, 'lng': 16.1833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.36, 13.8511]},
#    'id': '240',
#    'properties': {'city': 'Canicattì', 'lat': 37.36, 'lng': 13.8511}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [46.1408, 12.2156]},
#    'id': '241',
#    'properties': {'city': 'Belluno', 'lat': 46.1408, 'lng': 12.2156}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.6625, 14.8356]},
#    'id': '242',
#    'properties': {'city': 'Adrano', 'lat': 37.6625, 'lng': 14.8356}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.7333, 11.2833]},
#    'id': '243',
#    'properties': {'city': 'Cento', 'lat': 44.7333, 'lng': 11.2833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.49, 9.2953]},
#    'id': '244',
#    'properties': {'city': 'Segrate', 'lat': 45.49, 'lng': 9.2953}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.5972, 9.13]},
#    'id': '245',
#    'properties': {'city': 'Limbiate', 'lat': 45.5972, 'lng': 9.13}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.8872, 12.2969]},
#    'id': '246',
#    'properties': {'city': 'Conegliano', 'lat': 45.8872, 'lng': 12.2969}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.4861, 13.4821]},
#    'id': '247',
#    'properties': {'city': 'Osimo', 'lat': 43.4861, 'lng': 13.4821}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44, 12.65]},
#    'id': '248',
#    'properties': {'city': 'Riccione Marina', 'lat': 44, 'lng': 12.65}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42.2312, 14.3905]},
#    'id': '249',
#    'properties': {'city': 'Lanciano', 'lat': 42.2312, 'lng': 14.3905}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.9094, 14.2098]},
#    'id': '250',
#    'properties': {'city': 'Mugnano di Napoli',
#     'lat': 40.9094,
#     'lng': 14.2098}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.8725, 14.4369]},
#    'id': '251',
#    'properties': {'city': 'Somma Vesuviana', 'lat': 40.8725, 'lng': 14.4369}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.5508, 9.3011]},
#    'id': '252',
#    'properties': {'city': 'Brugherio', 'lat': 45.5508, 'lng': 9.3011}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.4333, 9.1167]},
#    'id': '253',
#    'properties': {'city': 'Corsico', 'lat': 45.4333, 'lng': 9.1167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.9352, 13.6193]},
#    'id': '254',
#    'properties': {'city': 'Gorizia', 'lat': 45.9352, 'lng': 13.6193}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.5739, 10.8478]},
#    'id': '255',
#    'properties': {'city': 'Formigine', 'lat': 44.5739, 'lng': 10.8478}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.5167, 9.3333]},
#    'id': '256',
#    'properties': {'city': 'Cernusco sul Naviglio',
#     'lat': 45.5167,
#     'lng': 9.3333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.3667, 9.6833]},
#    'id': '257',
#    'properties': {'city': 'Crema', 'lat': 45.3667, 'lng': 9.6833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.9153, 14.2681]},
#    'id': '258',
#    'properties': {'city': 'Arzano', 'lat': 40.9153, 'lng': 14.2681}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.7431, 14.5694]},
#    'id': '259',
#    'properties': {'city': 'Angri', 'lat': 40.7431, 'lng': 14.5694}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.7372, 7.3206]},
#    'id': '260',
#    'properties': {'city': 'Aosta', 'lat': 45.7372, 'lng': 7.3206}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.1342, 8.4583]},
#    'id': '261',
#    'properties': {'city': 'Casale Monferrato', 'lat': 45.1342, 'lng': 8.4583}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.9422, 14.2348]},
#    'id': '262',
#    'properties': {'city': 'Sant’Antimo', 'lat': 40.9422, 'lng': 14.2348}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42.9348, 10.5221]},
#    'id': '263',
#    'properties': {'city': 'Piombino', 'lat': 42.9348, 'lng': 10.5221}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [38.6753, 16.0959]},
#    'id': '264',
#    'properties': {'city': 'Vibo Valentia', 'lat': 38.6753, 'lng': 16.0959}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42.0028, 14.9947]},
#    'id': '265',
#    'properties': {'city': 'Termoli', 'lat': 42.0028, 'lng': 14.9947}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.1167, 7.6333]},
#    'id': '266',
#    'properties': {'city': 'Venaria Reale', 'lat': 45.1167, 'lng': 7.6333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.6667, 11.9333]},
#    'id': '267',
#    'properties': {'city': 'Castelfranco Veneto',
#     'lat': 45.6667,
#     'lng': 11.9333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.35, 10.85]},
#    'id': '268',
#    'properties': {'city': 'Villafranca di Verona',
#     'lat': 45.35,
#     'lng': 10.85}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.5, 15.3333]},
# ...
#    'id': '912',
#    'properties': {'city': 'Biassono', 'lat': 45.6306, 'lng': 9.2744}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [46.1114, 12.9017]},
#    'id': '913',
#    'properties': {'city': 'Spilimbergo', 'lat': 46.1114, 'lng': 12.9017}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.7833, 12.25]},
#    'id': '914',
#    'properties': {'city': 'Spresiano', 'lat': 45.7833, 'lng': 12.25}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.8081, 12.7372]},
#    'id': '915',
#    'properties': {'city': 'Monte Compatri', 'lat': 41.8081, 'lng': 12.7372}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.6, 9.5167]},
#    'id': '916',
#    'properties': {'city': 'Trezzo sull’Adda', 'lat': 45.6, 'lng': 9.5167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.7833, 10.3833]},
#    'id': '917',
#    'properties': {'city': 'Vecchiano', 'lat': 43.7833, 'lng': 10.3833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.3461, 18.0461]},
#    'id': '918',
#    'properties': {'city': 'Carmiano', 'lat': 40.3461, 'lng': 18.0461}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.7833, 12.7667]},
#    'id': '919',
#    'properties': {'city': 'Rocca Priora', 'lat': 41.7833, 'lng': 12.7667}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.8833, 12.1667]},
#    'id': '920',
#    'properties': {'city': 'Pieve di Soligo', 'lat': 45.8833, 'lng': 12.1667}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.5667, 11.9333]},
#    'id': '921',
#    'properties': {'city': 'Camposampiero', 'lat': 45.5667, 'lng': 11.9333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.5542, 11.4439]},
#    'id': '922',
#    'properties': {'city': 'Granarolo del l’Emilia',
#     'lat': 44.5542,
#     'lng': 11.4439}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.5164, 11.4597]},
#    'id': '923',
#    'properties': {'city': 'Altavilla Vicentina',
#     'lat': 45.5164,
#     'lng': 11.4597}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.0333, 16.75]},
#    'id': '924',
#    'properties': {'city': 'Bitetto', 'lat': 41.0333, 'lng': 16.75}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.5167, 9.1]},
#    'id': '925',
#    'properties': {'city': 'Baranzate', 'lat': 45.5167, 'lng': 9.1}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.5, 8.9333]},
#    'id': '926',
#    'properties': {'city': 'Arluno', 'lat': 45.5, 'lng': 8.9333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.9216, 11.5812]},
#    'id': '927',
#    'properties': {'city': 'Occhiobello', 'lat': 44.9216, 'lng': 11.5812}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.6167, 11.35]},
#    'id': '928',
#    'properties': {'city': 'Cornedo Vicentino', 'lat': 45.6167, 'lng': 11.35}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [39.9833, 18.0833]},
#    'id': '929',
#    'properties': {'city': 'Taviano', 'lat': 39.9833, 'lng': 18.0833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.8333, 13.5]},
#    'id': '930',
#    'properties': {'city': 'Ronchi dei Legionari',
#     'lat': 45.8333,
#     'lng': 13.5}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42.8167, 10.3167]},
#    'id': '931',
#    'properties': {'city': 'Portoferraio', 'lat': 42.8167, 'lng': 10.3167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.5061, 12.0411]},
#    'id': '932',
#    'properties': {'city': 'Alfonsine', 'lat': 44.5061, 'lng': 12.0411}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.3047, 18.2228]},
#    'id': '933',
#    'properties': {'city': 'Lizzanello', 'lat': 40.3047, 'lng': 18.2228}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.8928, 14.7194]},
#    'id': '934',
#    'properties': {'city': 'Monteforte Irpino',
#     'lat': 40.8928,
#     'lng': 14.7194}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.15, 7.65]},
#    'id': '935',
#    'properties': {'city': 'Borgaro Torinese', 'lat': 45.15, 'lng': 7.65}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.1, 12.4167]},
#    'id': '936',
#    'properties': {'city': 'San Mauro Pascoli', 'lat': 44.1, 'lng': 12.4167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.8667, 14.5333]},
#    'id': '937',
#    'properties': {'city': 'San Gennaro Vesuviano',
#     'lat': 40.8667,
#     'lng': 14.5333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.7167, 14.9333]},
#    'id': '938',
#    'properties': {'city': 'Giffoni Valle Piana',
#     'lat': 40.7167,
#     'lng': 14.9333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.1667, 15.1833]},
#    'id': '939',
#    'properties': {'city': 'Priolo Gargallo', 'lat': 37.1667, 'lng': 15.1833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.5667, 15.1167]},
#    'id': '940',
#    'properties': {'city': 'San Gregorio di Catania',
#     'lat': 37.5667,
#     'lng': 15.1167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.3, 14.2]},
#    'id': '941',
#    'properties': {'city': 'Mazzarino', 'lat': 37.3, 'lng': 14.2}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.85, 12.25]},
#    'id': '942',
#    'properties': {'city': 'Susegana', 'lat': 45.85, 'lng': 12.25}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42.5535, 12.4168]},
#    'id': '943',
#    'properties': {'city': 'Amelia', 'lat': 42.5535, 'lng': 12.4168}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.7636, 12.9953]},
#    'id': '944',
#    'properties': {'city': 'San Michele al Tagliamento',
#     'lat': 45.7636,
#     'lng': 12.9953}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.5209, 10.8362]},
#    'id': '945',
#    'properties': {'city': 'Sant’Ambrogio di Valpolicella',
#     'lat': 45.5209,
#     'lng': 10.8362}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.6, 8.75]},
#    'id': '946',
#    'properties': {'city': 'Lonate Pozzolo', 'lat': 45.6, 'lng': 8.75}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.3667, 16.15]},
#    'id': '947',
#    'properties': {'city': 'Margherita di Savoia',
#     'lat': 41.3667,
#     'lng': 16.15}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [39.95, 18.1667]},
#    'id': '948',
#    'properties': {'city': 'Taurisano', 'lat': 39.95, 'lng': 18.1667}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.6333, 12.75]},
#    'id': '949',
#    'properties': {'city': 'Campobello di Mazara',
#     'lat': 37.6333,
#     'lng': 12.75}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42.8, 13.9167]},
#    'id': '950',
#    'properties': {'city': 'Tortoreto', 'lat': 42.8, 'lng': 13.9167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [46.1667, 12.7167]},
#    'id': '951',
#    'properties': {'city': 'Maniago', 'lat': 46.1667, 'lng': 12.7167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.8333, 12.1167]},
#    'id': '952',
#    'properties': {'city': 'Codigoro', 'lat': 44.8333, 'lng': 12.1167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.9667, 15.8167]},
#    'id': '953',
#    'properties': {'city': 'Venosa', 'lat': 40.9667, 'lng': 15.8167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.9333, 12.7333]},
#    'id': '954',
#    'properties': {'city': 'Fiume Veneto', 'lat': 45.9333, 'lng': 12.7333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [39.54, 8.6267]},
#    'id': '955',
#    'properties': {'city': 'Guspini', 'lat': 39.54, 'lng': 8.6267}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.085, 11.6006]},
#    'id': '956',
#    'properties': {'city': 'Lendinara', 'lat': 45.085, 'lng': 11.6006}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [43.9, 10.8333]},
#    'id': '957',
#    'properties': {'city': 'Serravalle Pistoiese',
#     'lat': 43.9,
#     'lng': 10.8333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.5167, 11.6167]},
#    'id': '958',
#    'properties': {'city': 'Torri di Quartesolo',
#     'lat': 45.5167,
#     'lng': 11.6167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [38.05, 13.5333]},
#    'id': '959',
#    'properties': {'city': 'Casteldaccia', 'lat': 38.05, 'lng': 13.5333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.0833, 9.3]},
#    'id': '960',
#    'properties': {'city': 'Stradella', 'lat': 45.0833, 'lng': 9.3}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.7833, 8.9667]},
#    'id': '961',
#    'properties': {'city': 'Olgiate Comasco', 'lat': 45.7833, 'lng': 8.9667}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.7, 11.8]},
#    'id': '962',
#    'properties': {'city': 'Portomaggiore', 'lat': 44.7, 'lng': 11.8}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.1691, 8.3435]},
#    'id': '963',
#    'properties': {'city': 'Finale Ligure', 'lat': 44.1691, 'lng': 8.3435}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.6003, 12.8876]},
#    'id': '964',
#    'properties': {'city': 'Caorle', 'lat': 45.6003, 'lng': 12.8876}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.8463, 9.3582]},
#    'id': '965',
#    'properties': {'city': 'Valmadrera', 'lat': 45.8463, 'lng': 9.3582}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [42.1333, 12.3833]},
#    'id': '966',
#    'properties': {'city': 'Campagnano di Roma',
#     'lat': 42.1333,
#     'lng': 12.3833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.75, 17.4167]},
#    'id': '967',
#    'properties': {'city': 'Cisternino', 'lat': 40.75, 'lng': 17.4167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [38.1667, 13.2333]},
#    'id': '968',
#    'properties': {'city': 'Capaci', 'lat': 38.1667, 'lng': 13.2333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.2667, 11.1333]},
#    'id': '969',
#    'properties': {'city': 'Isola della Scala',
#     'lat': 45.2667,
#     'lng': 11.1333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.6833, 10.1833]},
#    'id': '970',
#    'properties': {'city': 'Gardone Val Trompia',
#     'lat': 45.6833,
#     'lng': 10.1833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.5743, 9.6963]},
#    'id': '971',
#    'properties': {'city': 'Siniscola', 'lat': 40.5743, 'lng': 9.6963}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.7439, 9.7594]},
#    'id': '972',
#    'properties': {'city': 'Nembro', 'lat': 45.7439, 'lng': 9.7594}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.3842, 17.3547]},
#    'id': '973',
#    'properties': {'city': 'Pulsano', 'lat': 40.3842, 'lng': 17.3547}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.6978, 9.5881]},
#    'id': '974',
#    'properties': {'city': 'Ponte San Pietro', 'lat': 45.6978, 'lng': 9.5881}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.45, 11.7667]},
#    'id': '975',
#    'properties': {'city': 'Mestrino', 'lat': 45.45, 'lng': 11.7667}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.6833, 13.5667]},
#    'id': '976',
#    'properties': {'city': 'Isola del Liri', 'lat': 41.6833, 'lng': 13.5667}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.4704, 10.2967]},
#    'id': '977',
#    'properties': {'city': 'Castenedolo', 'lat': 45.4704, 'lng': 10.2967}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.4035, 8.6827]},
#    'id': '978',
#    'properties': {'city': 'Arenzano', 'lat': 44.4035, 'lng': 8.6827}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.2678, 13.9697]},
#    'id': '979',
#    'properties': {'city': 'Ravanusa', 'lat': 37.2678, 'lng': 13.9697}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.6178, 12.565]},
#    'id': '980',
#    'properties': {'city': 'Musile di Piave', 'lat': 45.6178, 'lng': 12.565}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.3333, 11.7833]},
#    'id': '981',
#    'properties': {'city': 'Montegrotto Terme',
#     'lat': 45.3333,
#     'lng': 11.7833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.0333, 18.1333]},
#    'id': '982',
#    'properties': {'city': 'Matino', 'lat': 40.0333, 'lng': 18.1333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.4167, 9.4]},
#    'id': '983',
#    'properties': {'city': 'Paullo', 'lat': 45.4167, 'lng': 9.4}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.6436, 12.2953]},
#    'id': '984',
#    'properties': {'city': 'Casièr', 'lat': 45.6436, 'lng': 12.2953}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.2833, 14.0833]},
#    'id': '985',
#    'properties': {'city': 'Riesi', 'lat': 37.2833, 'lng': 14.0833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.8167, 12.9333]},
#    'id': '986',
#    'properties': {'city': 'Cave', 'lat': 41.8167, 'lng': 12.9333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.5333, 11.4833]},
#    'id': '987',
#    'properties': {'city': 'Creazzo', 'lat': 45.5333, 'lng': 11.4833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.6392, 8.6464]},
#    'id': '988',
#    'properties': {'city': 'Ovada', 'lat': 44.6392, 'lng': 8.6464}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [40.7333, 15.7167]},
#    'id': '989',
#    'properties': {'city': 'Avigliano', 'lat': 40.7333, 'lng': 15.7167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.6, 12.1667]},
#    'id': '990',
#    'properties': {'city': 'Zero Branco', 'lat': 45.6, 'lng': 12.1667}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.0253, 14.4925]},
#    'id': '991',
#    'properties': {'city': 'Acate', 'lat': 37.0253, 'lng': 14.4925}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.9833, 12.55]},
#    'id': '992',
#    'properties': {'city': 'Paceco', 'lat': 37.9833, 'lng': 12.55}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.5067, 10.9472]},
#    'id': '993',
#    'properties': {'city': 'Castelvetro di Modena',
#     'lat': 44.5067,
#     'lng': 10.9472}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [41.05, 16.8333]},
#    'id': '994',
#    'properties': {'city': 'Bitritto', 'lat': 41.05, 'lng': 16.8333}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.6118, 11.5076]},
#    'id': '995',
#    'properties': {'city': 'Caldogno', 'lat': 45.6118, 'lng': 11.5076}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [44.7667, 10.45]},
#    'id': '996',
#    'properties': {'city': 'Sant’Ilario d’Enza', 'lat': 44.7667, 'lng': 10.45}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [45.5167, 11.7167]},
#    'id': '997',
#    'properties': {'city': 'Camisano Vicentino',
#     'lat': 45.5167,
#     'lng': 11.7167}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [37.9167, 15.7833]},
#    'id': '998',
#    'properties': {'city': 'Melito di Porto Salvo',
#     'lat': 37.9167,
#     'lng': 15.7833}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [38.05, 13.3833]},
#    'id': '999',
#    'properties': {'city': 'Belmonte Mezzagno', 'lat': 38.05, 'lng': 13.3833}},
#   ...]}

# %% [markdown]
# **7. Extract the raster values for each features**
#
# We will use sampleRegions function from ee.image and apply to image collection

# %%
def rasterExtraction(image):
    feature = image.sampleRegions(
        collection = ee_fc, # feature collection here
        scale = 10 # Cell size of raster
    )
    return feature

# %% [markdown]
# **8. Apply raster extraction functions over image collection**
#
# - `sampleRegions` returns feature collection with image values, then we have collection of feature collection which is then flattened to obtain final feature collection.
#
# - Finally feature collection is converted to CSV.

# %%
results = Sentinel_data.filterBounds(ee_fc).select('NDVI', 'EVI').map(addDate).map(rasterExtraction).flatten()

# %% [markdown]
# **9.Verify that output is as per your requirments**

# %%
sample_result = results.first().getInfo()
sample_result
# Out:
# {'type': 'Feature',
#  'geometry': None,
#  'id': '20210101T075331_20210101T075325_T37PBP_1461_0',
#  'properties': {'EVI': 0.16712218289349878,
#   'NDVI': 0.2624911963939667,
#   'city': 'Pantelleria',
#   'date': 20210101,
#   'lat': 36.7875,
#   'lng': 11.9925}}

# %% [markdown]
# **10. Now we have extracted the raster values, We need to convert feature collection to CSV format.**
#
# We can acheive this in multiple ways, I will illustrate in 3 ways for extraction.

# %%
# extract the properties column from feature collection
# column order may not be as our sample data order
columns = list(sample_result['properties'].keys())
print(columns)


# Order data column as per sample data
# You can modify this for better optimization
column_df = list(italy_df.columns)
column_df.extend(['NDVI', 'EVI', 'date'])
print(column_df)
# Out:
# ['EVI', 'NDVI', 'city', 'date', 'lat', 'lng']
# ['city', 'lat', 'lng', 'NDVI', 'EVI', 'date']

# %% [markdown]
# **11.Method 1: Feature collection to pandas dataframe**

# %%
nested_list = results.reduceColumns(ee.Reducer.toList(len(column_df)), column_df).values().get(0)
data = nested_list.getInfo()
data

# dont forget we need to call the callback method "getInfo" to retrieve the data
df = pd.DataFrame(data, columns=column_df)
# we obtain the data frame as per our demand
df

# %% [markdown]
# **Data visualization of results:**

# %%
# import libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# plot line plot for single point only.
df_filtered = df[df['id']==1]
df_filtered['date'] = pd.to_datetime(df_filtered['date'], format='%Y%m%d')
df_filtered

# %%
# Using plotly.express
import plotly.express as px

# %%
df = px.data.stocks()
fig = px.line(df_filtered, x='date', y="EVI")
fig.show()df = px.data.stocks()

# %%
fig = px.line(df_filtered, x='date', y="NDVI")
fig.show()
