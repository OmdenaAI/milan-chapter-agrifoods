# %% [markdown]
# # Omdena  - Milan Chapter Agrifoods
# ## AI for Sustainable agri-food systems: use of Satellite Imagery
# ### Exploratory analysis of grapes and olives production in Italy 2006-2022
# #### Author: Maria Fisher

# %% [markdown]
# The main objective of this study is to have gather information about crop production in Italy for the period of 2006-2022.
#
# Crop dataset used in this study was downloaded from the Italian National Institute of Statistics (Istat).

# %%
import warnings 
warnings.filterwarnings("ignore")

import os
import pandas as pd
pd.options.display.float_format = "{:.2f}".format
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
import seaborn as sns 
import scipy 
import sklearn
import geopandas as gpd
import pgeocode
import folium
import sys
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot, plot

# %%
grapes_olives = pd.read_csv('./Italy_crop_data/grapes_olives.csv',skipinitialspace=True)
grapes_olives.head()
# Out:
#   ITTER107 Territory TIPO_DATO5                         Data type AGRI_MADRE  \
# 0    ITE17      Pisa   HP_Q_EXT  harvested production - quintals       OLIVO
# 1    ITE17      Pisa   HP_Q_EXT  harvested production - quintals       OLIVO
# 2    ITE17      Pisa   HP_Q_EXT  harvested production - quintals       OLIVO
# 3    ITE17      Pisa   HP_Q_EXT  harvested production - quintals       OLIVO
# 4    ITE17      Pisa   HP_Q_EXT  harvested production - quintals       OLIVO
#
#   Type of crop  TIME  Select time     Value Flag Codes          Flags
# 0   oil olives  2006         2006 125000.00        NaN            NaN
# 1   oil olives  2007         2007  30702.00        NaN            NaN
# 2   oil olives  2008         2008 145292.00        NaN            NaN
# 3   oil olives  2009         2009 100000.00        NaN            NaN
# 4   oil olives  2010         2010  95459.00          e  estimate data

# %% [markdown]
# ## Pre-processing dataset

# %%
# Drop Columns
grapes_olives = grapes_olives.drop(columns =['ITTER107','TIPO_DATO5','AGRI_MADRE', 'TIME', 'Flag Codes','Flags' ])
grapes_olives
# Out:
#                             Territory                         Data type  \
# 0                                Pisa  harvested production - quintals
# 1                                Pisa  harvested production - quintals
# 2                                Pisa  harvested production - quintals
# 3                                Pisa  harvested production - quintals
# 4                                Pisa  harvested production - quintals
# ...                               ...                               ...
# 17616  Valle d'Aosta / Vallée d'Aoste       production area - hectares
# 17617  Valle d'Aosta / Vallée d'Aoste      total production - quintals
# 17618  Valle d'Aosta / Vallée d'Aoste  harvested production - quintals
# 17619                          Milano       production area - hectares
# 17620                         Ferrara             total area - hectares
#
#        Type of crop  Select time     Value
# 0        oil olives         2006 125000.00
# 1        oil olives         2007  30702.00
# 2        oil olives         2008 145292.00
# 3        oil olives         2009 100000.00
# 4        oil olives         2010  95459.00
# ...             ...          ...       ...
# 17616  other olives         2021      1.00
# 17617  other olives         2021     40.00
# 17618  other olives         2021     40.00
# 17619  other olives         2021      2.00
# 17620  table olives         2021      1.00
#
# [17621 rows x 5 columns]

# %%
# Rename Columns
grapes_olives = grapes_olives.rename(columns = {'Select time':'Year', 'Type of crop':'Type_crop', 'Data type':'Data_type', 'Territory':'City'})

# %%
grapes_olives = grapes_olives[grapes_olives["Year"] < 2022]

# %%
def show_info(grapes_olives):
    print('DATASET SHAPE: ', grapes_olives.shape, '\n')
    print('-'*50)
    print('FEATURE DATA TYPES:')
    print(grapes_olives.info())
    print('\n', '-'*50)
    print('NUMBER OF UNIQUE VALUES PER FEATURE:', '\n')
    print(grapes_olives.nunique())
    print('\n', '-'*50)
    print('NULL VALUES PER FEATURE')
    print(grapes_olives.isnull().sum())
show_info(grapes_olives)
# Out:
# DATASET SHAPE:  (17248, 5)
#
# --------------------------------------------------
# FEATURE DATA TYPES:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17248 entries, 0 to 17620
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   City       17248 non-null  object
#  1   Data_type  17248 non-null  object
#  2   Type_crop  17248 non-null  object
#  3   Year       17248 non-null  int64
#  4   Value      17248 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 808.5+ KB
# None
#
#  --------------------------------------------------
# NUMBER OF UNIQUE VALUES PER FEATURE:
#
# City          109
# Data_type       6
# Type_crop      21
# Year           16
# Value        6442
# dtype: int64
#
#  --------------------------------------------------
# NULL VALUES PER FEATURE
# City         0
# Data_type    0
# Type_crop    0
# Year         0
# Value        0
# dtype: int64

# %% [markdown]
# ## Cities in Italy producing grapes_olives

# %%
# Check cities names
grapes_olives.City.unique()
# Out:
# array(['Pisa', 'Ascoli Piceno', 'Ferrara', 'Livorno', 'Lucca', 'Palermo',
#        'Isernia', 'Rieti', 'Foggia', 'Gorizia', 'Macerata', 'Pescara',
#        'Cagliari', 'Novara', 'Pesaro e Urbino', 'Vibo Valentia', 'Rovigo',
#        'Verona', 'Cuneo', 'Taranto', 'Bari', 'Firenze', 'Benevento',
#        'Olbia-Tempio', 'Enna', 'Cosenza', 'Frosinone', 'Latina', 'Asti',
#        'Genova', 'Caserta', 'Siracusa', 'Brindisi', 'Lecco', 'Bergamo',
#        'Sassari', 'Terni', 'Belluno', 'Pordenone', 'Caltanissetta',
#        'Medio Campidano', 'Parma', 'Ogliastra', 'Piacenza', 'Catania',
#        'Carbonia-Iglesias', 'Catanzaro', 'Reggio di Calabria', 'Crotone',
#        'Treviso', 'Ragusa', 'Oristano', 'Udine', 'Matera', 'Bologna',
#        'Imperia', "L'Aquila", 'Biella', 'Salerno', 'Campobasso', 'Lecce',
#        'La Spezia', 'Agrigento', 'Teramo', 'Savona', 'Napoli', 'Mantova',
#        'Torino', 'Chieti', 'Alessandria', 'Varese', 'Sondrio',
#        'Verbano-Cusio-Ossola', 'Pavia', 'Massa-Carrara',
#        "Reggio nell'Emilia", 'Potenza', 'Messina', 'Nuoro', 'Pistoia',
#        'Modena', 'Padova', 'Perugia', 'Ravenna', 'Trieste', 'Prato',
#        'Vicenza', 'Avellino', 'Grosseto', 'Roma', 'Venezia', 'Trapani',
#        'Brescia', 'Vercelli', 'Viterbo', 'Arezzo', 'Forlì-Cesena',
#        'Siena', 'Ancona', "Valle d'Aosta / Vallée d'Aoste", 'Milano',
#        'Rimini', 'Como', 'Cremona', 'Lodi', 'Monza e della Brianza',
#        'Fermo', 'Barletta-Andria-Trani', 'Sud Sardegna'], dtype=object)

# %%
grapes_olives1 =  grapes_olives.loc[ grapes_olives['Data_type'] == 'total production - quintals ']

# %%
grapes_olives1['total_production'] = grapes_olives1['Value'][grapes_olives1['Data_type']=='total production - quintals ']
grapes_olives1.head(10)
# Out:
#      City                     Data_type Type_crop  Year    Value  \
# 60  Lucca  total production - quintals       wine  2006 54310.00
# 61  Lucca  total production - quintals       wine  2007 46900.00
# 62  Lucca  total production - quintals       wine  2008 45208.00
# 63  Lucca  total production - quintals       wine  2009 44900.00
# 64  Lucca  total production - quintals       wine  2010 34580.00
# 65  Lucca  total production - quintals       wine  2011 28960.00
# 66  Lucca  total production - quintals       wine  2012 27350.00
# 67  Lucca  total production - quintals       wine  2013 33000.00
# 68  Lucca  total production - quintals       wine  2014 35416.00
# 69  Lucca  total production - quintals       wine  2015 22116.00
#
#     total_production
# 60          54310.00
# 61          46900.00
# 62          45208.00
# 63          44900.00
# 64          34580.00
# 65          28960.00
# 66          27350.00
# 67          33000.00
# 68          35416.00
# 69          22116.00

# %%
grapes_olives2 =  grapes_olives.loc[ grapes_olives['Data_type'] == 'total area - hectares']
grapes_olives2
# Out:
#                                  City              Data_type  \
# 15                      Ascoli Piceno  total area - hectares
# 16                      Ascoli Piceno  total area - hectares
# 17                      Ascoli Piceno  total area - hectares
# 18                      Ascoli Piceno  total area - hectares
# 19                      Ascoli Piceno  total area - hectares
# ...                               ...                    ...
# 17605                    Sud Sardegna  total area - hectares
# 17606                    Sud Sardegna  total area - hectares
# 17614                        Grosseto  total area - hectares
# 17615  Valle d'Aosta / Vallée d'Aoste  total area - hectares
# 17620                         Ferrara  total area - hectares
#
#                   Type_crop  Year    Value
# 15     Grapes for table use  2006    33.00
# 16     Grapes for table use  2007    33.00
# 17     Grapes for table use  2008    33.00
# 18     Grapes for table use  2009    30.00
# 19     Grapes for table use  2010    15.00
# ...                     ...   ...      ...
# 17605          other olives  2020 12870.00
# 17606          other olives  2021 12870.00
# 17614          table olives  2021     1.00
# 17615          other olives  2021     1.00
# 17620          table olives  2021     1.00
#
# [2126 rows x 5 columns]

# %%
grapes_olives2['total_area_ha'] = grapes_olives2['Value'][grapes_olives2['Data_type']=='total area - hectares']
grapes_olives2.tail(10)
# Out:
#                                  City              Data_type     Type_crop  \
# 17582                        Oristano  total area - hectares  other olives
# 17589                           Fermo  total area - hectares  other olives
# 17590                           Fermo  total area - hectares  other olives
# 17597           Barletta-Andria-Trani  total area - hectares  other olives
# 17598           Barletta-Andria-Trani  total area - hectares  other olives
# 17605                    Sud Sardegna  total area - hectares  other olives
# 17606                    Sud Sardegna  total area - hectares  other olives
# 17614                        Grosseto  total area - hectares  table olives
# 17615  Valle d'Aosta / Vallée d'Aoste  total area - hectares  other olives
# 17620                         Ferrara  total area - hectares  table olives
#
#        Year    Value  total_area_ha
# 17582  2021  4534.00        4534.00
# 17589  2020  1653.00        1653.00
# 17590  2021  1653.00        1653.00
# 17597  2020 33300.00       33300.00
# 17598  2021 33300.00       33300.00
# 17605  2020 12870.00       12870.00
# 17606  2021 12870.00       12870.00
# 17614  2021     1.00           1.00
# 17615  2021     1.00           1.00
# 17620  2021     1.00           1.00

# %%
# Join both datasets 
grapes_olives_total =  pd.merge_ordered(grapes_olives1, grapes_olives2, on=['Year', 'City', 'Type_crop'], how='left')
grapes_olives_total
# Out:
#              City                   Data_type_x  \
# 0       Agrigento  total production - quintals
# 1       Agrigento  total production - quintals
# 2       Agrigento  total production - quintals
# 3     Alessandria  total production - quintals
# 4     Alessandria  total production - quintals
# ...           ...                           ...
# 5064      Viterbo  total production - quintals
# 5065      Viterbo  total production - quintals
# 5066      Viterbo  total production - quintals
# 5067      Viterbo  total production - quintals
# 5068      Viterbo  total production - quintals
#
#                                               Type_crop  Year    Value_x  \
# 0                                  Grapes for table use  2006 1417500.00
# 1                                             olive oil  2006   92870.00
# 2                                                  wine  2006 1190000.00
# 3                                  Grapes for table use  2006    3825.00
# 4                                                  wine  2006  902605.00
# ...                                                 ...   ...        ...
# 5064  grapes for wines with protected designation of...  2021   78800.00
# 5065  grapes for wines with protected geographical i...  2021  115000.00
# 5066                                         oil olives  2021  218000.00
# 5067                                          olive oil  2021   23900.00
# 5068                                       other olives  2021  218000.00
#
#       total_production            Data_type_y  Value_y  total_area_ha
# 0           1417500.00  total area - hectares  6770.00        6770.00
# 1             92870.00                    NaN      NaN            NaN
# 2           1190000.00                    NaN      NaN            NaN
# 3              3825.00  total area - hectares    37.00          37.00
# 4            902605.00                    NaN      NaN            NaN
# ...                ...                    ...      ...            ...
# 5064          78800.00  total area - hectares   870.00         870.00
# 5065         115000.00  total area - hectares  1300.00        1300.00
# 5066         218000.00  total area - hectares 14900.00       14900.00
# 5067          23900.00                    NaN      NaN            NaN
# 5068         218000.00  total area - hectares 14900.00       14900.00
#
# [5069 rows x 9 columns]

# %%
grapes_olives_total = grapes_olives_total.drop(columns =['Data_type_x','Data_type_y', 'Value_x', 'Value_y' ])
grapes_olives_total
# Out:
#              City                                          Type_crop  Year  \
# 0       Agrigento                               Grapes for table use  2006
# 1       Agrigento                                          olive oil  2006
# 2       Agrigento                                               wine  2006
# 3     Alessandria                               Grapes for table use  2006
# 4     Alessandria                                               wine  2006
# ...           ...                                                ...   ...
# 5064      Viterbo  grapes for wines with protected designation of...  2021
# 5065      Viterbo  grapes for wines with protected geographical i...  2021
# 5066      Viterbo                                         oil olives  2021
# 5067      Viterbo                                          olive oil  2021
# 5068      Viterbo                                       other olives  2021
#
#       total_production  total_area_ha
# 0           1417500.00        6770.00
# 1             92870.00            NaN
# 2           1190000.00            NaN
# 3              3825.00          37.00
# 4            902605.00            NaN
# ...                ...            ...
# 5064          78800.00         870.00
# 5065         115000.00        1300.00
# 5066         218000.00       14900.00
# 5067          23900.00            NaN
# 5068         218000.00       14900.00
#
# [5069 rows x 5 columns]

# %%
# Transform values from quintals to tonnes
grapes_olives_total['total_production'] = grapes_olives_total['total_production']/10
grapes_olives_total
# Out:
#              City                                          Type_crop  Year  \
# 0       Agrigento                               Grapes for table use  2006
# 1       Agrigento                                          olive oil  2006
# 2       Agrigento                                               wine  2006
# 3     Alessandria                               Grapes for table use  2006
# 4     Alessandria                                               wine  2006
# ...           ...                                                ...   ...
# 5064      Viterbo  grapes for wines with protected designation of...  2021
# 5065      Viterbo  grapes for wines with protected geographical i...  2021
# 5066      Viterbo                                         oil olives  2021
# 5067      Viterbo                                          olive oil  2021
# 5068      Viterbo                                       other olives  2021
#
#       total_production  total_area_ha
# 0            141750.00        6770.00
# 1              9287.00            NaN
# 2            119000.00            NaN
# 3               382.50          37.00
# 4             90260.50            NaN
# ...                ...            ...
# 5064           7880.00         870.00
# 5065          11500.00        1300.00
# 5066          21800.00       14900.00
# 5067           2390.00            NaN
# 5068          21800.00       14900.00
#
# [5069 rows x 5 columns]

# %%
# Rename column value to production tonnes
grapes_olives_total = grapes_olives_total.rename(columns = {'total_production':'production_tonnes'})
grapes_olives_total
# Out:
#              City                                          Type_crop  Year  \
# 0       Agrigento                               Grapes for table use  2006
# 1       Agrigento                                          olive oil  2006
# 2       Agrigento                                               wine  2006
# 3     Alessandria                               Grapes for table use  2006
# 4     Alessandria                                               wine  2006
# ...           ...                                                ...   ...
# 5064      Viterbo  grapes for wines with protected designation of...  2021
# 5065      Viterbo  grapes for wines with protected geographical i...  2021
# 5066      Viterbo                                         oil olives  2021
# 5067      Viterbo                                          olive oil  2021
# 5068      Viterbo                                       other olives  2021
#
#       production_tonnes  total_area_ha
# 0             141750.00        6770.00
# 1               9287.00            NaN
# 2             119000.00            NaN
# 3                382.50          37.00
# 4              90260.50            NaN
# ...                 ...            ...
# 5064            7880.00         870.00
# 5065           11500.00        1300.00
# 5066           21800.00       14900.00
# 5067            2390.00            NaN
# 5068           21800.00       14900.00
#
# [5069 rows x 5 columns]

# %%
# Import climate dataset
climate_mean = pd.read_csv('climate2006-2021_mean.csv')
climate_mean.head()
# Out:
#    Unnamed: 0.1         City  Year  Unnamed: 0     PS    TS  QV2M  RH2M  WS2M  \
# 0             0  Abano Terme  2006           6 100.76 13.30  7.32 71.53  1.56
# 1             1  Abano Terme  2007          19 100.66 14.06  7.23 68.75  1.59
# 2             2  Abano Terme  2008          32 100.63 13.64  7.72 73.95  1.67
# 3             3  Abano Terme  2009          45 100.47 13.71  7.72 72.75  1.69
# 4             4  Abano Terme  2010          58 100.33 12.55  7.54 75.60  1.70
#
#    GWETTOP  T2M_MAX  T2M_MIN  GWETPROF  GWETROOT  CLOUD_AMT  T2M_RANGE  \
# 0     0.66    25.65     3.84      0.65      0.67      56.54      21.80
# 1     0.61    26.09     4.63      0.61      0.63      54.11      21.47
# 2     0.69    24.69     4.30      0.67      0.70      59.45      20.38
# 3     0.70    24.92     4.11      0.70      0.72      57.77      20.82
# 4     0.75    23.83     2.73      0.73      0.76      61.55      21.10
#
#    PRECTOTCORR
# 0         1.68
# 1         1.94
# 2         2.77
# 3         2.45
# 4         3.15

# %%
# Check cities names
climate_mean.City.unique()
# Out:
# array(['Abano Terme', 'Abbadia Lariana', 'Abbadia San Salvatore', ...,
#        'Zogno', 'Zola Predosa', 'Zoppola'], dtype=object)

# %%
# Select cities names that correlate with crop data 

climate_mean = climate_mean.apply(lambda row: row[climate_mean['City'].isin(['Agrigento', 'Alessandria', 'Ancona', 'Arezzo', 'Ascoli Piceno',
                                                                             'Asti', 'Avellino', 'Bari', 'Barletta-Andria-Trani', 'Belluno',
                                                                             'Benevento', 'Bergamo', 'Biella', 'Bologna', 'Bolzano / Bozen',
                                                                             'Brescia', 'Brindisi', 'Cagliari', 'Caltanissetta', 'Campobasso',
                                                                             'Carbonia-Iglesias', 'Caserta', 'Catania', 'Catanzaro', 'Chieti',
                                                                             'Como', 'Cosenza', 'Cremona', 'Crotone', 'Cuneo', 'Enna', 'Fermo',
                                                                             'Ferrara', 'Firenze', 'Foggia', 'Forlì-Cesena', 'Frosinone',
                                                                             'Genova', 'Gorizia', 'Grosseto', 'Imperia', 'Isernia', "L'Aquila",
                                                                             'La Spezia', 'Latina', 'Lecce', 'Lecco', 'Livorno', 'Lodi',
                                                                             'Lucca', 'Macerata', 'Mantova', 'Massa-Carrara', 'Matera',
                                                                             'Medio Campidano', 'Messina', 'Milano', 'Modena',
                                                                             'Monza e della Brianza', 'Napoli', 'Novara', 'Nuoro', 'Ogliastra',
                                                                             'Olbia-Tempio', 'Oristano', 'Padova', 'Palermo', 'Parma', 'Pavia',
                                                                             'Perugia', 'Pesaro e Urbino', 'Pescara', 'Piacenza', 'Pisa',
                                                                             'Pistoia', 'Pordenone', 'Potenza', 'Prato', 'Ragusa', 'Ravenna',
                                                                             'Reggio di Calabria', "Reggio nell'Emilia", 'Rieti', 'Rimini',
                                                                             'Roma', 'Rovigo', 'Salerno', 'Sassari', 'Savona', 'Siena',
                                                                             'Siracusa', 'Sondrio', 'Sud Sardegna', 'Taranto', 'Teramo',
                                                                             'Terni', 'Torino', 'Trapani', 'Trentino Alto Adige / Südtirol',
                                                                             'Trento', 'Treviso', 'Trieste', 'Udine',
                                                                             "Valle d'Aosta / Vallée d'Aoste", 'Varese', 'Venezia',
                                                                             'Verbano-Cusio-Ossola', 'Vercelli', 'Verona', 'Vibo Valentia',
                                                                             'Vicenza', 'Viterbo'])])

climate_mean.head()
# Out:
#      Unnamed: 0.1       City  Year  Unnamed: 0    PS    TS  QV2M  RH2M  WS2M  \
# 603           603  Agrigento  2006           6 96.87 16.70  8.33 71.95  2.61
# 604           604  Agrigento  2007          19 96.80 17.18  8.35 71.72  2.75
# 605           605  Agrigento  2008          32 96.83 16.91  8.27 71.72  2.66
# 606           606  Agrigento  2009          45 96.63 16.22  8.67 75.45  2.73
# 607           607  Agrigento  2010          58 96.57 16.20  8.60 75.71  2.87
#
#      GWETTOP  T2M_MAX  T2M_MIN  GWETPROF  GWETROOT  CLOUD_AMT  T2M_RANGE  \
# 603     0.58    28.51     6.77      0.61      0.62      39.63      21.74
# 604     0.55    28.65     7.18      0.59      0.60      41.58      21.47
# 605     0.58    28.02     6.84      0.61      0.61      39.13      21.19
# 606     0.70    26.94     7.30      0.72      0.73      42.54      19.64
# 607     0.69    26.97     6.97      0.71      0.72      46.03      19.99
#
#      PRECTOTCORR
# 603         1.58
# 604         1.78
# 605         1.61
# 606         2.82
# 607         2.79

# %%
climate_mean.City.unique()
# Out:
# array(['Agrigento', 'Alessandria', 'Ancona',
#        "Valle d'Aosta / Vallée d'Aoste", 'Arezzo', 'Ascoli Piceno',
#        'Asti', 'Avellino', 'Bari', 'Barletta-Andria-Trani', 'Belluno',
#        'Benevento', 'Bergamo', 'Biella', 'Bologna', 'Bolzano / Bozen',
#        'Brescia', 'Brindisi', 'Sud Sardegna', 'Caltanissetta',
#        'Campobasso', 'Carbonia-Iglesias', 'Caserta', 'Catania',
#        'Catanzaro', 'Chieti', 'Latina', 'Como', 'Cosenza', 'Cremona',
#        'Crotone', 'Cuneo', 'Enna', 'Fermo', 'Ferrara', 'Firenze',
#        'Foggia', 'Frosinone', 'Genova', 'Gorizia', 'Grosseto', 'Imperia',
#        'Isernia', 'La Spezia', 'Ogliastra', 'Lecce', 'Lecco', 'Livorno',
#        'Lodi', 'Lucca', 'Macerata', 'Mantova', 'Matera', 'Messina',
#        'Milano', 'Modena', 'Treviso', 'Monza e della Brianza', 'Napoli',
#        'Novara', 'Nuoro', 'Olbia-Tempio', 'Oristano', 'Padova', 'Palermo',
#        'Parma', 'Pavia', 'Perugia', 'Pesaro e Urbino', 'Pescara',
#        'Piacenza', 'Pisa', 'Pistoia', 'Pordenone', 'Potenza', 'Prato',
#        'Ragusa', 'Ravenna', "Reggio nell'Emilia", 'Reggio di Calabria',
#        'Rieti', 'Rimini', 'Torino', 'Rovigo', 'Salerno',
#        'Medio Campidano', 'Sassari', 'Savona', 'Siena', 'Siracusa',
#        'Sondrio', 'Taranto', 'Teramo', 'Terni',
#        'Trentino Alto Adige / Südtirol', 'Trapani', 'Trento', 'Roma',
#        'Trieste', 'Udine', 'Varese', 'Venezia', 'Verbano-Cusio-Ossola',
#        'Vercelli', 'Verona', 'Vibo Valentia', 'Vicenza', 'Viterbo'],
#       dtype=object)

# %%
# Join both crop and climate datasets 
climate_grapes_olives = pd.merge_ordered(grapes_olives_total, climate_mean,  left_by="City").fillna(0)

# %%
climate_grapes_olives.head()
# Out:
#         City             Type_crop  Year  production_tonnes  total_area_ha  \
# 0  Agrigento  Grapes for table use  2006          141750.00        6770.00
# 1  Agrigento             olive oil  2006            9287.00           0.00
# 2  Agrigento                  wine  2006          119000.00           0.00
# 3  Agrigento  Grapes for table use  2007          126521.30        6595.00
# 4  Agrigento             olive oil  2007            9510.00           0.00
#
#    Unnamed: 0.1  Unnamed: 0    PS    TS  QV2M  RH2M  WS2M  GWETTOP  T2M_MAX  \
# 0        603.00        6.00 96.87 16.70  8.33 71.95  2.61     0.58    28.51
# 1        603.00        6.00 96.87 16.70  8.33 71.95  2.61     0.58    28.51
# 2        603.00        6.00 96.87 16.70  8.33 71.95  2.61     0.58    28.51
# 3        604.00       19.00 96.80 17.18  8.35 71.72  2.75     0.55    28.65
# 4        604.00       19.00 96.80 17.18  8.35 71.72  2.75     0.55    28.65
#
#    T2M_MIN  GWETPROF  GWETROOT  CLOUD_AMT  T2M_RANGE  PRECTOTCORR
# 0     6.77      0.61      0.62      39.63      21.74         1.58
# 1     6.77      0.61      0.62      39.63      21.74         1.58
# 2     6.77      0.61      0.62      39.63      21.74         1.58
# 3     7.18      0.59      0.60      41.58      21.47         1.78
# 4     7.18      0.59      0.60      41.58      21.47         1.78

# %%
climate_grapes_olives =  climate_grapes_olives.to_csv('grapes_olives_climate_2006-2021.csv', index=False)

# %%
climate_grapes_olives = pd.read_csv('grapes_olives_climate_2006-2021.csv',skipinitialspace=True)
climate_grapes_olives.head()
# Out:
#         City             Type_crop  Year  production_tonnes  total_area_ha  \
# 0  Agrigento  Grapes for table use  2006          141750.00        6770.00
# 1  Agrigento             olive oil  2006            9287.00           0.00
# 2  Agrigento                  wine  2006          119000.00           0.00
# 3  Agrigento  Grapes for table use  2007          126521.30        6595.00
# 4  Agrigento             olive oil  2007            9510.00           0.00
#
#    Unnamed: 0.1  Unnamed: 0    PS    TS  QV2M  RH2M  WS2M  GWETTOP  T2M_MAX  \
# 0        603.00        6.00 96.87 16.70  8.33 71.95  2.61     0.58    28.51
# 1        603.00        6.00 96.87 16.70  8.33 71.95  2.61     0.58    28.51
# 2        603.00        6.00 96.87 16.70  8.33 71.95  2.61     0.58    28.51
# 3        604.00       19.00 96.80 17.18  8.35 71.72  2.75     0.55    28.65
# 4        604.00       19.00 96.80 17.18  8.35 71.72  2.75     0.55    28.65
#
#    T2M_MIN  GWETPROF  GWETROOT  CLOUD_AMT  T2M_RANGE  PRECTOTCORR
# 0     6.77      0.61      0.62      39.63      21.74         1.58
# 1     6.77      0.61      0.62      39.63      21.74         1.58
# 2     6.77      0.61      0.62      39.63      21.74         1.58
# 3     7.18      0.59      0.60      41.58      21.47         1.78
# 4     7.18      0.59      0.60      41.58      21.47         1.78

# %% [markdown]
# Import fertilizers data

# %%
fertilizer = pd.read_csv('Italy_crop_data/fertilizer2006-2021.csv',skipinitialspace=True)
fertilizer.head()
# Out:
#      City    Type_fertilizer  Year  Fertilizers_tonnes
# 0  Torino  calcium cyanamide  2006              122.70
# 1  Torino  calcium cyanamide  2007              181.20
# 2  Torino  calcium cyanamide  2008              522.40
# 3  Torino  calcium cyanamide  2009              205.10
# 4  Torino  calcium cyanamide  2010                5.40

# %% [markdown]
# Join crop and fertilizers datasets

# %%
# Join both crop and fertilizers datasets 
crop_fertilizer_climate = pd.merge(climate_grapes_olives , fertilizer, on=['Year', 'City'], how='left').fillna(0)
crop_fertilizer_climate
# Out:
#                City             Type_crop  Year  production_tonnes  \
# 0         Agrigento  Grapes for table use  2006          141750.00
# 1         Agrigento  Grapes for table use  2006          141750.00
# 2         Agrigento  Grapes for table use  2006          141750.00
# 3         Agrigento  Grapes for table use  2006          141750.00
# 4         Agrigento  Grapes for table use  2006          141750.00
# ...             ...                   ...   ...                ...
# 51952  Sud Sardegna          table olives  2021            4573.30
# 51953  Sud Sardegna          table olives  2021            4573.30
# 51954  Sud Sardegna          table olives  2021            4573.30
# 51955  Sud Sardegna          table olives  2021            4573.30
# 51956  Sud Sardegna          table olives  2021            4573.30
#
#        total_area_ha  Unnamed: 0.1  Unnamed: 0     PS    TS  QV2M  ...  \
# 0            6770.00        603.00        6.00  96.87 16.70  8.33  ...
# 1            6770.00        603.00        6.00  96.87 16.70  8.33  ...
# 2            6770.00        603.00        6.00  96.87 16.70  8.33  ...
# 3            6770.00        603.00        6.00  96.87 16.70  8.33  ...
# 4            6770.00        603.00        6.00  96.87 16.70  8.33  ...
# ...              ...           ...         ...    ...   ...   ...  ...
# 51952        2534.00       7170.00      136.00 100.92 19.17 10.55  ...
# 51953        2534.00       7170.00      136.00 100.92 19.17 10.55  ...
# 51954        2534.00       7170.00      136.00 100.92 19.17 10.55  ...
# 51955        2534.00       7170.00      136.00 100.92 19.17 10.55  ...
# 51956        2534.00       7170.00      136.00 100.92 19.17 10.55  ...
#
#        GWETTOP  T2M_MAX  T2M_MIN  GWETPROF  GWETROOT  CLOUD_AMT  T2M_RANGE  \
# 0         0.58    28.51     6.77      0.61      0.62      39.63      21.74
# 1         0.58    28.51     6.77      0.61      0.62      39.63      21.74
# 2         0.58    28.51     6.77      0.61      0.62      39.63      21.74
# 3         0.58    28.51     6.77      0.61      0.62      39.63      21.74
# 4         0.58    28.51     6.77      0.61      0.62      39.63      21.74
# ...        ...      ...      ...       ...       ...        ...        ...
# 51952     0.89    23.78    13.52      0.56      0.58      49.54      10.26
# 51953     0.89    23.78    13.52      0.56      0.58      49.54      10.26
# 51954     0.89    23.78    13.52      0.56      0.58      49.54      10.26
# 51955     0.89    23.78    13.52      0.56      0.58      49.54      10.26
# 51956     0.89    23.78    13.52      0.56      0.58      49.54      10.26
#
#        PRECTOTCORR     Type_fertilizer  Fertilizers_tonnes
# 0             1.58   calcium cyanamide                0.00
# 1             1.58  nitrogen-potassium               27.70
# 2             1.58         peaty-amend              174.50
# 3             1.58    organic-nitrogen              760.50
# 4             1.58             organic             1343.70
# ...            ...                 ...                 ...
# 51952         2.78  nitrogen-potassium              113.00
# 51953         2.78    organic-nitrogen              221.00
# 51954         2.78             organic                0.00
# 51955         2.78         peaty-amend                0.00
# 51956         2.78         peaty-amend                0.00
#
# [51957 rows x 22 columns]

# %%
# Save crop and fertilizers joined data
crop_fertilizer_climate  =  crop_fertilizer_climate.to_csv('grapes_olives_fertilizer_climate_2006-2021.csv', index=False)

# %%
crop_fertilizer_climate = pd.read_csv('grapes_olives_fertilizer_climate_2006-2021.csv',skipinitialspace=True)
crop_fertilizer_climate.head()
# Out:
#         City             Type_crop  Year  production_tonnes  total_area_ha  \
# 0  Agrigento  Grapes for table use  2006          141750.00        6770.00
# 1  Agrigento  Grapes for table use  2006          141750.00        6770.00
# 2  Agrigento  Grapes for table use  2006          141750.00        6770.00
# 3  Agrigento  Grapes for table use  2006          141750.00        6770.00
# 4  Agrigento  Grapes for table use  2006          141750.00        6770.00
#
#    Unnamed: 0.1  Unnamed: 0    PS    TS  QV2M  ...  GWETTOP  T2M_MAX  T2M_MIN  \
# 0        603.00        6.00 96.87 16.70  8.33  ...     0.58    28.51     6.77
# 1        603.00        6.00 96.87 16.70  8.33  ...     0.58    28.51     6.77
# 2        603.00        6.00 96.87 16.70  8.33  ...     0.58    28.51     6.77
# 3        603.00        6.00 96.87 16.70  8.33  ...     0.58    28.51     6.77
# 4        603.00        6.00 96.87 16.70  8.33  ...     0.58    28.51     6.77
#
#    GWETPROF  GWETROOT  CLOUD_AMT  T2M_RANGE  PRECTOTCORR     Type_fertilizer  \
# 0      0.61      0.62      39.63      21.74         1.58   calcium cyanamide
# 1      0.61      0.62      39.63      21.74         1.58  nitrogen-potassium
# 2      0.61      0.62      39.63      21.74         1.58         peaty-amend
# 3      0.61      0.62      39.63      21.74         1.58    organic-nitrogen
# 4      0.61      0.62      39.63      21.74         1.58             organic
#
#    Fertilizers_tonnes
# 0                0.00
# 1               27.70
# 2              174.50
# 3              760.50
# 4             1343.70
#
# [5 rows x 22 columns]

# %% [markdown]
# Import locations lat and lon

# %%
geo = pd.read_csv('it_locations2.csv',skipinitialspace=True)
geo.head()
# Out:
#       City   lat   lon
# 0     Roma 41.89 12.48
# 1   Milano 45.47  9.19
# 2   Napoli 40.83 14.25
# 3    Turin 45.07  7.70
# 4  Palermo 38.12 13.36

# %%
geo.City.unique()
# Out:
# array(['Roma', 'Milano', 'Napoli', ..., 'Tollegno', 'Revere',
#        'Rive d’Arcano'], dtype=object)

# %%
# Select cities that correlate with crop data 

geo = geo.apply(lambda row: row[geo['City'].isin(['Agrigento', 'Alessandria', 'Ancona', 'Arezzo', 'Ascoli Piceno',
                                                                             'Asti', 'Avellino', 'Bari', 'Barletta-Andria-Trani', 'Belluno',
                                                                             'Benevento', 'Bergamo', 'Biella', 'Bologna', 'Bolzano / Bozen',
                                                                             'Brescia', 'Brindisi', 'Cagliari', 'Caltanissetta', 'Campobasso',
                                                                             'Carbonia-Iglesias', 'Caserta', 'Catania', 'Catanzaro', 'Chieti',
                                                                             'Como', 'Cosenza', 'Cremona', 'Crotone', 'Cuneo', 'Enna', 'Fermo',
                                                                             'Ferrara', 'Firenze', 'Foggia', 'Forlì-Cesena', 'Frosinone',
                                                                             'Genova', 'Gorizia', 'Grosseto', 'Imperia', 'Isernia', "L'Aquila",
                                                                             'La Spezia', 'Latina', 'Lecce', 'Lecco', 'Livorno', 'Lodi',
                                                                             'Lucca', 'Macerata', 'Mantova', 'Massa-Carrara', 'Matera',
                                                                             'Medio Campidano', 'Messina', 'Milano', 'Modena',
                                                                             'Monza e della Brianza', 'Napoli', 'Novara', 'Nuoro', 'Ogliastra',
                                                                             'Olbia-Tempio', 'Oristano', 'Padova', 'Palermo', 'Parma', 'Pavia',
                                                                             'Perugia', 'Pesaro e Urbino', 'Pescara', 'Piacenza', 'Pisa',
                                                                             'Pistoia', 'Pordenone', 'Potenza', 'Prato', 'Ragusa', 'Ravenna',
                                                                             'Reggio di Calabria', "Reggio nell'Emilia", 'Rieti', 'Rimini',
                                                                             'Roma', 'Rovigo', 'Salerno', 'Sassari', 'Savona', 'Siena',
                                                                             'Siracusa', 'Sondrio', 'Sud Sardegna', 'Taranto', 'Teramo',
                                                                             'Terni', 'Torino', 'Trapani', 'Trentino Alto Adige / Südtirol',
                                                                             'Trento', 'Treviso', 'Trieste', 'Udine',
                                                                             "Valle d'Aosta / Vallée d'Aoste", 'Varese', 'Venezia',
                                                                             'Verbano-Cusio-Ossola', 'Vercelli', 'Verona', 'Vibo Valentia',
                                                                             'Vicenza', 'Viterbo'])])
geo.head()
# Out:
#       City   lat   lon
# 0     Roma 41.89 12.48
# 1   Milano 45.47  9.19
# 2   Napoli 40.83 14.25
# 4  Palermo 38.12 13.36
# 5   Genova 44.41  8.93

# %%
geo.City.unique()
# Out:
# array(['Roma', 'Milano', 'Napoli', 'Palermo', 'Genova', 'Bologna',
#        'Firenze', 'Bari', 'Catania', 'Venezia', 'Verona', 'Messina',
#        'Padova', 'Trieste', 'Taranto', 'Brescia', 'Parma', 'Prato',
#        'Modena', 'Reggio di Calabria', "Reggio nell'Emilia", 'Perugia',
#        'Ravenna', 'Livorno', 'Cagliari', 'Foggia', 'Rimini', 'Salerno',
#        'Ferrara', 'Latina', 'Monza e della Brianza', 'Siracusa',
#        'Bergamo', 'Pescara', 'Trento', 'Sassari', 'Vicenza', 'Terni',
#        'Bolzano / Bozen', 'Novara', 'Piacenza', 'Ancona', 'Udine',
#        'Arezzo', 'Forlì-Cesena', 'Lecce', 'Pesaro e Urbino',
#        'Barletta-Andria-Trani', 'Alessandria', 'La Spezia', 'Pistoia',
#        'Pisa', 'Catanzaro', 'Lucca', 'Brindisi', 'Treviso', 'Como',
#        'Grosseto', 'Varese', 'Asti', 'Caserta', 'Ragusa', 'Pavia',
#        'Cremona', 'Trapani', 'Viterbo', 'Cosenza', 'Potenza', 'Crotone',
#        'Massa-Carrara', 'Caltanissetta', 'Benevento', 'Savona', 'Matera',
#        'Olbia-Tempio', 'Agrigento', 'Cuneo', 'Teramo', 'Avellino',
#        'Siena', 'Rovigo', 'Pordenone', 'Chieti', 'Mantova', 'Campobasso',
#        'Ascoli Piceno', 'Lecco', 'Rieti', 'Vercelli', 'Frosinone', 'Lodi',
#        'Biella', 'Imperia', 'Macerata', 'Fermo', 'Nuoro', 'Belluno',
#        'Gorizia', "Valle d'Aosta / Vallée d'Aoste", 'Vibo Valentia',
#        'Oristano', 'Verbano-Cusio-Ossola', 'Carbonia-Iglesias', 'Enna',
#        'Isernia', 'Sondrio', 'Medio Campidano', 'Ogliastra',
#        'Trentino Alto Adige / Südtirol', 'Torino'], dtype=object)

# %%
# Join both crop and locations datasets 
crop_fertilizer_climate = pd.merge_ordered(crop_fertilizer_climate, geo,  left_by="City").fillna(0)

# %%
crop_fertilizer_climate
# Out:
#                City             Type_crop  Year  production_tonnes  \
# 0         Agrigento  Grapes for table use  2006          141750.00
# 1         Agrigento  Grapes for table use  2006          141750.00
# 2         Agrigento  Grapes for table use  2006          141750.00
# 3         Agrigento  Grapes for table use  2006          141750.00
# 4         Agrigento  Grapes for table use  2006          141750.00
# ...             ...                   ...   ...                ...
# 51952  Sud Sardegna          table olives  2021            4573.30
# 51953  Sud Sardegna          table olives  2021            4573.30
# 51954  Sud Sardegna          table olives  2021            4573.30
# 51955  Sud Sardegna          table olives  2021            4573.30
# 51956  Sud Sardegna          table olives  2021            4573.30
#
#        total_area_ha  Unnamed: 0.1  Unnamed: 0     PS    TS  QV2M  ...  \
# 0            6770.00        603.00        6.00  96.87 16.70  8.33  ...
# 1            6770.00        603.00        6.00  96.87 16.70  8.33  ...
# 2            6770.00        603.00        6.00  96.87 16.70  8.33  ...
# 3            6770.00        603.00        6.00  96.87 16.70  8.33  ...
# 4            6770.00        603.00        6.00  96.87 16.70  8.33  ...
# ...              ...           ...         ...    ...   ...   ...  ...
# 51952        2534.00       7170.00      136.00 100.92 19.17 10.55  ...
# 51953        2534.00       7170.00      136.00 100.92 19.17 10.55  ...
# 51954        2534.00       7170.00      136.00 100.92 19.17 10.55  ...
# 51955        2534.00       7170.00      136.00 100.92 19.17 10.55  ...
# 51956        2534.00       7170.00      136.00 100.92 19.17 10.55  ...
#
#        T2M_MIN  GWETPROF  GWETROOT  CLOUD_AMT  T2M_RANGE  PRECTOTCORR  \
# 0         6.77      0.61      0.62      39.63      21.74         1.58
# 1         6.77      0.61      0.62      39.63      21.74         1.58
# 2         6.77      0.61      0.62      39.63      21.74         1.58
# 3         6.77      0.61      0.62      39.63      21.74         1.58
# 4         6.77      0.61      0.62      39.63      21.74         1.58
# ...        ...       ...       ...        ...        ...          ...
# 51952    13.52      0.56      0.58      49.54      10.26         2.78
# 51953    13.52      0.56      0.58      49.54      10.26         2.78
# 51954    13.52      0.56      0.58      49.54      10.26         2.78
# 51955    13.52      0.56      0.58      49.54      10.26         2.78
# 51956    13.52      0.56      0.58      49.54      10.26         2.78
#
#           Type_fertilizer  Fertilizers_tonnes   lat   lon
# 0       calcium cyanamide                0.00 37.31 13.58
# 1      nitrogen-potassium               27.70 37.31 13.58
# 2             peaty-amend              174.50 37.31 13.58
# 3        organic-nitrogen              760.50 37.31 13.58
# 4                 organic             1343.70 37.31 13.58
# ...                   ...                 ...   ...   ...
# 51952  nitrogen-potassium              113.00  0.00  0.00
# 51953    organic-nitrogen              221.00  0.00  0.00
# 51954             organic                0.00  0.00  0.00
# 51955         peaty-amend                0.00  0.00  0.00
# 51956         peaty-amend                0.00  0.00  0.00
#
# [51957 rows x 24 columns]

# %%
# Save final dataset
crop_fertilizer_climate  =  crop_fertilizer_climate.to_csv('grapes-olives_final_2006-2021.csv', index=False)
